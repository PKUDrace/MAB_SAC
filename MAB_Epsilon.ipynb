# %%
import gymnasium as gym 
from gymnasium import spaces
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import make_interp_spline
from stable_baselines3 import SAC
from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.callbacks import BaseCallback

# %%
class MAB(gym.Env):
    def __init__(self, probs, T):
        """
        初始化多臂老虎机环境
        probs: 每个臂的成功概率
        T: 总时间步数
        """
        super(MAB, self).__init__()
        self.k = len(probs)  # 臂的数量
        self.probs = probs  # 每个臂的成功概率
        self.T = T  # 总时间步数

        # 定义动作空间和观察空间
        self.action_space = spaces.Box(low=0, high=1, shape=(1,), dtype=np.float32)  # 动作空间为epsilon\in[0,1],表示epsilon-greedy策略
        self.observation_space = spaces.Box(low=0, high=np.inf, shape=(3 * self.k + 1,))  # 观察空间为(3*k+1)维向量，每个维度包含三个元素：拉臂的次数、获得的奖励、奖励的方差，以及最后一个元素是时间t
        self.reset()

    def reset(self, seed=None, options=None):
        """
        重置环境
        返回: 初始状态
        """
        super().reset(seed=seed)
        self.steps = 0
        self.n = np.zeros(self.k)  # 每个臂的拉动次数
        self.average_rewards = np.zeros(self.k)  # 每个臂奖励的均值
        self.rewards = [[] for _ in range(self.k)]  # 每个臂的奖励列表
        self.var = np.zeros(self.k) # 每个臂奖励的方差
        self.action = 1.0  # 初始epsilon值
        observation = np.zeros(3 * self.k + 1)  # 初始状态
        info = {}
        return observation, info
    
    def step(self, action):
        """
        执行给定的动作，并返回结果。
        
        参数:
        action: 智能体选择的epsilon值
        
        返回:
        - next_state: 执行动作后的新状态
        - reward: 执行动作后获得的奖励
        - terminated: 布尔值，表示是否达到终止状态
        - truncated: 布尔值，表示是否由于时间限制或其他原因而被截断
        - info: 额外的诊断信息（可选）
        """
        self.action = action[0]  # 更新action值
        # 按照epsilon-greedy策略选择动作
        if np.random.rand() < self.action:
            chosen_arm = np.random.choice(self.k)
        else:
            # 选择奖励均值最大的臂
            chosen_arm = np.argmax(self.average_rewards)
            
        reward = np.random.binomial(1, self.probs[chosen_arm])  # 根据奖励概率生成奖励
        
        self.steps += 1
        self.n[chosen_arm] += 1
        self.rewards[chosen_arm].append(reward)  # 更新奖励列表
        self.average_rewards[chosen_arm] = np.mean(self.rewards[chosen_arm])  # 更新奖励均值
        self.var[chosen_arm] = np.var(self.rewards[chosen_arm])#更新奖励方差
        terminated = self.steps >= self.T  # 判断是否达到最大步数
        truncated = self.steps >= self.T  # 在这个示例中，截断条件与终止条件相同
        next_state = np.concatenate([self.n, self.average_rewards, self.var, [self.steps]])  # 更新状态
        info = {} # 可选的额外信息

        return next_state, reward, terminated, truncated, info

# %%
# 创建环境
np.random.seed(1)
probs = np.random.rand(5)
formatted_probs = [f"{prob:.4f}" for prob in probs]
print("伯努利多臂老虎机的概率为：", formatted_probs)
T = 50
env = MAB(probs,T)

class CustomCallback(BaseCallback):
    def __init__(self, verbose=0):
        super(CustomCallback, self).__init__(verbose)

    def _on_step(self) -> bool:
        # 打印当前时间步
        print(f"当前时间步: {self.num_timesteps}")
        return True
# 创建模型
model = SAC("MlpPolicy", env ,gamma=1,verbose=2) #  我们模型中的折线因子为1

# 创建自定义回调函数实例
callback = CustomCallback()

# 训练模型，并传入回调函数
model.learn(total_timesteps=5000, log_interval=4, callback=callback)

# 保存模型
model.save("EpsilonGreedy")
# Out:
# 伯努利多臂老虎机的概率为： ['0.4170', '0.7203', '0.0001', '0.3023', '0.1468']
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# 当前时间步: 1
# 当前时间步: 2
# 当前时间步: 3
# 当前时间步: 4
# 当前时间步: 5
# 当前时间步: 6
# 当前时间步: 7
# 当前时间步: 8
# 当前时间步: 9
# 当前时间步: 10
# 当前时间步: 11
# 当前时间步: 12
# 当前时间步: 13
# 当前时间步: 14
# 当前时间步: 15
# 当前时间步: 16
# 当前时间步: 17
# 当前时间步: 18
# 当前时间步: 19
# 当前时间步: 20
# 当前时间步: 21
# 当前时间步: 22
# 当前时间步: 23
# 当前时间步: 24
# 当前时间步: 25
# 当前时间步: 26
# 当前时间步: 27
# 当前时间步: 28
# 当前时间步: 29
# 当前时间步: 30
# 当前时间步: 31
# 当前时间步: 32
# 当前时间步: 33
# 当前时间步: 34
# 当前时间步: 35
# 当前时间步: 36
# 当前时间步: 37
# 当前时间步: 38
# 当前时间步: 39
# 当前时间步: 40
# 当前时间步: 41
# 当前时间步: 42
# 当前时间步: 43
# 当前时间步: 44
# 当前时间步: 45
# 当前时间步: 46
# 当前时间步: 47
# 当前时间步: 48
# 当前时间步: 49
# 当前时间步: 50
# 当前时间步: 51
# 当前时间步: 52
# 当前时间步: 53
# 当前时间步: 54
# 当前时间步: 55
# 当前时间步: 56
# 当前时间步: 57
# 当前时间步: 58
# 当前时间步: 59
# 当前时间步: 60
# 当前时间步: 61
# 当前时间步: 62
# 当前时间步: 63
# 当前时间步: 64
# 当前时间步: 65
# 当前时间步: 66
# 当前时间步: 67
# 当前时间步: 68
# 当前时间步: 69
# 当前时间步: 70
# 当前时间步: 71
# 当前时间步: 72
# 当前时间步: 73
# 当前时间步: 74
# 当前时间步: 75
# 当前时间步: 76
# 当前时间步: 77
# 当前时间步: 78
# 当前时间步: 79
# 当前时间步: 80
# 当前时间步: 81
# 当前时间步: 82
# 当前时间步: 83
# 当前时间步: 84
# 当前时间步: 85
# 当前时间步: 86
# 当前时间步: 87
# 当前时间步: 88
# 当前时间步: 89
# 当前时间步: 90
# 当前时间步: 91
# 当前时间步: 92
# 当前时间步: 93
# 当前时间步: 94
# 当前时间步: 95
# 当前时间步: 96
# 当前时间步: 97
# 当前时间步: 98
# 当前时间步: 99
# 当前时间步: 100
# 当前时间步: 101
# 当前时间步: 102
# 当前时间步: 103
# 当前时间步: 104
# 当前时间步: 105
# 当前时间步: 106
# 当前时间步: 107
# 当前时间步: 108
# 当前时间步: 109
# 当前时间步: 110
# 当前时间步: 111
# 当前时间步: 112
# 当前时间步: 113
# 当前时间步: 114
# 当前时间步: 115
# 当前时间步: 116
# 当前时间步: 117
# 当前时间步: 118
# 当前时间步: 119
# 当前时间步: 120
# 当前时间步: 121
# 当前时间步: 122
# 当前时间步: 123
# 当前时间步: 124
# 当前时间步: 125
# 当前时间步: 126
# 当前时间步: 127
# 当前时间步: 128
# 当前时间步: 129
# 当前时间步: 130
# 当前时间步: 131
# 当前时间步: 132
# 当前时间步: 133
# 当前时间步: 134
# 当前时间步: 135
# 当前时间步: 136
# 当前时间步: 137
# 当前时间步: 138
# 当前时间步: 139
# 当前时间步: 140
# 当前时间步: 141
# 当前时间步: 142
# 当前时间步: 143
# 当前时间步: 144
# 当前时间步: 145
# 当前时间步: 146
# 当前时间步: 147
# 当前时间步: 148
# 当前时间步: 149
# 当前时间步: 150
# 当前时间步: 151
# 当前时间步: 152
# 当前时间步: 153
# 当前时间步: 154
# 当前时间步: 155
# 当前时间步: 156
# 当前时间步: 157
# 当前时间步: 158
# 当前时间步: 159
# 当前时间步: 160
# 当前时间步: 161
# 当前时间步: 162
# 当前时间步: 163
# 当前时间步: 164
# 当前时间步: 165
# 当前时间步: 166
# 当前时间步: 167
# 当前时间步: 168
# 当前时间步: 169
# 当前时间步: 170
# 当前时间步: 171
# 当前时间步: 172
# 当前时间步: 173
# 当前时间步: 174
# 当前时间步: 175
# 当前时间步: 176
# 当前时间步: 177
# 当前时间步: 178
# 当前时间步: 179
# 当前时间步: 180
# 当前时间步: 181
# 当前时间步: 182
# 当前时间步: 183
# 当前时间步: 184
# 当前时间步: 185
# 当前时间步: 186
# 当前时间步: 187
# 当前时间步: 188
# 当前时间步: 189
# 当前时间步: 190
# 当前时间步: 191
# 当前时间步: 192
# 当前时间步: 193
# 当前时间步: 194
# 当前时间步: 195
# 当前时间步: 196
# 当前时间步: 197
# 当前时间步: 198
# 当前时间步: 199
# 当前时间步: 200
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 24.2     |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 292      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 200      |
# | train/             |          |
# |    actor_loss      | -2.11    |
# |    critic_loss     | 0.272    |
# |    ent_coef        | 0.971    |
# |    ent_coef_loss   | -0.0487  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 99       |
# ---------------------------------
# 当前时间步: 201
# 当前时间步: 202
# 当前时间步: 203
# 当前时间步: 204
# 当前时间步: 205
# 当前时间步: 206
# 当前时间步: 207
# 当前时间步: 208
# 当前时间步: 209
# 当前时间步: 210
# 当前时间步: 211
# 当前时间步: 212
# 当前时间步: 213
# 当前时间步: 214
# 当前时间步: 215
# 当前时间步: 216
# 当前时间步: 217
# 当前时间步: 218
# 当前时间步: 219
# 当前时间步: 220
# 当前时间步: 221
# 当前时间步: 222
# 当前时间步: 223
# 当前时间步: 224
# 当前时间步: 225
# 当前时间步: 226
# 当前时间步: 227
# 当前时间步: 228
# 当前时间步: 229
# 当前时间步: 230
# 当前时间步: 231
# 当前时间步: 232
# 当前时间步: 233
# 当前时间步: 234
# 当前时间步: 235
# 当前时间步: 236
# 当前时间步: 237
# 当前时间步: 238
# 当前时间步: 239
# 当前时间步: 240
# 当前时间步: 241
# 当前时间步: 242
# 当前时间步: 243
# 当前时间步: 244
# 当前时间步: 245
# 当前时间步: 246
# 当前时间步: 247
# 当前时间步: 248
# 当前时间步: 249
# 当前时间步: 250
# 当前时间步: 251
# 当前时间步: 252
# 当前时间步: 253
# 当前时间步: 254
# 当前时间步: 255
# 当前时间步: 256
# 当前时间步: 257
# 当前时间步: 258
# 当前时间步: 259
# 当前时间步: 260
# 当前时间步: 261
# 当前时间步: 262
# 当前时间步: 263
# 当前时间步: 264
# 当前时间步: 265
# 当前时间步: 266
# 当前时间步: 267
# 当前时间步: 268
# 当前时间步: 269
# 当前时间步: 270
# 当前时间步: 271
# 当前时间步: 272
# 当前时间步: 273
# 当前时间步: 274
# 当前时间步: 275
# 当前时间步: 276
# 当前时间步: 277
# 当前时间步: 278
# 当前时间步: 279
# 当前时间步: 280
# 当前时间步: 281
# 当前时间步: 282
# 当前时间步: 283
# 当前时间步: 284
# 当前时间步: 285
# 当前时间步: 286
# 当前时间步: 287
# 当前时间步: 288
# 当前时间步: 289
# 当前时间步: 290
# 当前时间步: 291
# 当前时间步: 292
# 当前时间步: 293
# 当前时间步: 294
# 当前时间步: 295
# 当前时间步: 296
# 当前时间步: 297
# 当前时间步: 298
# 当前时间步: 299
# 当前时间步: 300
# 当前时间步: 301
# 当前时间步: 302
# 当前时间步: 303
# 当前时间步: 304
# 当前时间步: 305
# 当前时间步: 306
# 当前时间步: 307
# 当前时间步: 308
# 当前时间步: 309
# 当前时间步: 310
# 当前时间步: 311
# 当前时间步: 312
# 当前时间步: 313
# 当前时间步: 314
# 当前时间步: 315
# 当前时间步: 316
# 当前时间步: 317
# 当前时间步: 318
# 当前时间步: 319
# 当前时间步: 320
# 当前时间步: 321
# 当前时间步: 322
# 当前时间步: 323
# 当前时间步: 324
# 当前时间步: 325
# 当前时间步: 326
# 当前时间步: 327
# 当前时间步: 328
# 当前时间步: 329
# 当前时间步: 330
# 当前时间步: 331
# 当前时间步: 332
# 当前时间步: 333
# 当前时间步: 334
# 当前时间步: 335
# 当前时间步: 336
# 当前时间步: 337
# 当前时间步: 338
# 当前时间步: 339
# 当前时间步: 340
# 当前时间步: 341
# 当前时间步: 342
# 当前时间步: 343
# 当前时间步: 344
# 当前时间步: 345
# 当前时间步: 346
# 当前时间步: 347
# 当前时间步: 348
# 当前时间步: 349
# 当前时间步: 350
# 当前时间步: 351
# 当前时间步: 352
# 当前时间步: 353
# 当前时间步: 354
# 当前时间步: 355
# 当前时间步: 356
# 当前时间步: 357
# 当前时间步: 358
# 当前时间步: 359
# 当前时间步: 360
# 当前时间步: 361
# 当前时间步: 362
# 当前时间步: 363
# 当前时间步: 364
# 当前时间步: 365
# 当前时间步: 366
# 当前时间步: 367
# 当前时间步: 368
# 当前时间步: 369
# 当前时间步: 370
# 当前时间步: 371
# 当前时间步: 372
# 当前时间步: 373
# 当前时间步: 374
# 当前时间步: 375
# 当前时间步: 376
# 当前时间步: 377
# 当前时间步: 378
# 当前时间步: 379
# 当前时间步: 380
# 当前时间步: 381
# 当前时间步: 382
# 当前时间步: 383
# 当前时间步: 384
# 当前时间步: 385
# 当前时间步: 386
# 当前时间步: 387
# 当前时间步: 388
# 当前时间步: 389
# 当前时间步: 390
# 当前时间步: 391
# 当前时间步: 392
# 当前时间步: 393
# 当前时间步: 394
# 当前时间步: 395
# 当前时间步: 396
# 当前时间步: 397
# 当前时间步: 398
# 当前时间步: 399
# 当前时间步: 400
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 23       |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 197      |
# |    time_elapsed    | 2        |
# |    total_timesteps | 400      |
# | train/             |          |
# |    actor_loss      | -2.47    |
# |    critic_loss     | 0.233    |
# |    ent_coef        | 0.914    |
# |    ent_coef_loss   | -0.15    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 299      |
# ---------------------------------
# 当前时间步: 401
# 当前时间步: 402
# 当前时间步: 403
# 当前时间步: 404
# 当前时间步: 405
# 当前时间步: 406
# 当前时间步: 407
# 当前时间步: 408
# 当前时间步: 409
# 当前时间步: 410
# 当前时间步: 411
# 当前时间步: 412
# 当前时间步: 413
# 当前时间步: 414
# 当前时间步: 415
# 当前时间步: 416
# 当前时间步: 417
# 当前时间步: 418
# 当前时间步: 419
# 当前时间步: 420
# 当前时间步: 421
# 当前时间步: 422
# 当前时间步: 423
# 当前时间步: 424
# 当前时间步: 425
# 当前时间步: 426
# 当前时间步: 427
# 当前时间步: 428
# 当前时间步: 429
# 当前时间步: 430
# 当前时间步: 431
# 当前时间步: 432
# 当前时间步: 433
# 当前时间步: 434
# 当前时间步: 435
# 当前时间步: 436
# 当前时间步: 437
# 当前时间步: 438
# 当前时间步: 439
# 当前时间步: 440
# 当前时间步: 441
# 当前时间步: 442
# 当前时间步: 443
# 当前时间步: 444
# 当前时间步: 445
# 当前时间步: 446
# 当前时间步: 447
# 当前时间步: 448
# 当前时间步: 449
# 当前时间步: 450
# 当前时间步: 451
# 当前时间步: 452
# 当前时间步: 453
# 当前时间步: 454
# 当前时间步: 455
# 当前时间步: 456
# 当前时间步: 457
# 当前时间步: 458
# 当前时间步: 459
# 当前时间步: 460
# 当前时间步: 461
# 当前时间步: 462
# 当前时间步: 463
# 当前时间步: 464
# 当前时间步: 465
# 当前时间步: 466
# 当前时间步: 467
# 当前时间步: 468
# 当前时间步: 469
# 当前时间步: 470
# 当前时间步: 471
# 当前时间步: 472
# 当前时间步: 473
# 当前时间步: 474
# 当前时间步: 475
# 当前时间步: 476
# 当前时间步: 477
# 当前时间步: 478
# 当前时间步: 479
# 当前时间步: 480
# 当前时间步: 481
# 当前时间步: 482
# 当前时间步: 483
# 当前时间步: 484
# 当前时间步: 485
# 当前时间步: 486
# 当前时间步: 487
# 当前时间步: 488
# 当前时间步: 489
# 当前时间步: 490
# 当前时间步: 491
# 当前时间步: 492
# 当前时间步: 493
# 当前时间步: 494
# 当前时间步: 495
# 当前时间步: 496
# 当前时间步: 497
# 当前时间步: 498
# 当前时间步: 499
# 当前时间步: 500
# 当前时间步: 501
# 当前时间步: 502
# 当前时间步: 503
# 当前时间步: 504
# 当前时间步: 505
# 当前时间步: 506
# 当前时间步: 507
# 当前时间步: 508
# 当前时间步: 509
# 当前时间步: 510
# 当前时间步: 511
# 当前时间步: 512
# 当前时间步: 513
# 当前时间步: 514
# 当前时间步: 515
# 当前时间步: 516
# 当前时间步: 517
# 当前时间步: 518
# 当前时间步: 519
# 当前时间步: 520
# 当前时间步: 521
# 当前时间步: 522
# 当前时间步: 523
# 当前时间步: 524
# 当前时间步: 525
# 当前时间步: 526
# 当前时间步: 527
# 当前时间步: 528
# 当前时间步: 529
# 当前时间步: 530
# 当前时间步: 531
# 当前时间步: 532
# 当前时间步: 533
# 当前时间步: 534
# 当前时间步: 535
# 当前时间步: 536
# 当前时间步: 537
# 当前时间步: 538
# 当前时间步: 539
# 当前时间步: 540
# 当前时间步: 541
# 当前时间步: 542
# 当前时间步: 543
# 当前时间步: 544
# 当前时间步: 545
# 当前时间步: 546
# 当前时间步: 547
# 当前时间步: 548
# 当前时间步: 549
# 当前时间步: 550
# 当前时间步: 551
# 当前时间步: 552
# 当前时间步: 553
# 当前时间步: 554
# 当前时间步: 555
# 当前时间步: 556
# 当前时间步: 557
# 当前时间步: 558
# 当前时间步: 559
# 当前时间步: 560
# 当前时间步: 561
# 当前时间步: 562
# 当前时间步: 563
# 当前时间步: 564
# 当前时间步: 565
# 当前时间步: 566
# 当前时间步: 567
# 当前时间步: 568
# 当前时间步: 569
# 当前时间步: 570
# 当前时间步: 571
# 当前时间步: 572
# 当前时间步: 573
# 当前时间步: 574
# 当前时间步: 575
# 当前时间步: 576
# 当前时间步: 577
# 当前时间步: 578
# 当前时间步: 579
# 当前时间步: 580
# 当前时间步: 581
# 当前时间步: 582
# 当前时间步: 583
# 当前时间步: 584
# 当前时间步: 585
# 当前时间步: 586
# 当前时间步: 587
# 当前时间步: 588
# 当前时间步: 589
# 当前时间步: 590
# 当前时间步: 591
# 当前时间步: 592
# 当前时间步: 593
# 当前时间步: 594
# 当前时间步: 595
# 当前时间步: 596
# 当前时间步: 597
# 当前时间步: 598
# 当前时间步: 599
# 当前时间步: 600
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 22.9     |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 177      |
# |    time_elapsed    | 3        |
# |    total_timesteps | 600      |
# | train/             |          |
# |    actor_loss      | -3.17    |
# |    critic_loss     | 0.233    |
# |    ent_coef        | 0.86     |
# |    ent_coef_loss   | -0.249   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 499      |
# ---------------------------------
# 当前时间步: 601
# 当前时间步: 602
# 当前时间步: 603
# 当前时间步: 604
# 当前时间步: 605
# 当前时间步: 606
# 当前时间步: 607
# 当前时间步: 608
# 当前时间步: 609
# 当前时间步: 610
# 当前时间步: 611
# 当前时间步: 612
# 当前时间步: 613
# 当前时间步: 614
# 当前时间步: 615
# 当前时间步: 616
# 当前时间步: 617
# 当前时间步: 618
# 当前时间步: 619
# 当前时间步: 620
# 当前时间步: 621
# 当前时间步: 622
# 当前时间步: 623
# 当前时间步: 624
# 当前时间步: 625
# 当前时间步: 626
# 当前时间步: 627
# 当前时间步: 628
# 当前时间步: 629
# 当前时间步: 630
# 当前时间步: 631
# 当前时间步: 632
# 当前时间步: 633
# 当前时间步: 634
# 当前时间步: 635
# 当前时间步: 636
# 当前时间步: 637
# 当前时间步: 638
# 当前时间步: 639
# 当前时间步: 640
# 当前时间步: 641
# 当前时间步: 642
# 当前时间步: 643
# 当前时间步: 644
# 当前时间步: 645
# 当前时间步: 646
# 当前时间步: 647
# 当前时间步: 648
# 当前时间步: 649
# 当前时间步: 650
# 当前时间步: 651
# 当前时间步: 652
# 当前时间步: 653
# 当前时间步: 654
# 当前时间步: 655
# 当前时间步: 656
# 当前时间步: 657
# 当前时间步: 658
# 当前时间步: 659
# 当前时间步: 660
# 当前时间步: 661
# 当前时间步: 662
# 当前时间步: 663
# 当前时间步: 664
# 当前时间步: 665
# 当前时间步: 666
# 当前时间步: 667
# 当前时间步: 668
# 当前时间步: 669
# 当前时间步: 670
# 当前时间步: 671
# 当前时间步: 672
# 当前时间步: 673
# 当前时间步: 674
# 当前时间步: 675
# 当前时间步: 676
# 当前时间步: 677
# 当前时间步: 678
# 当前时间步: 679
# 当前时间步: 680
# 当前时间步: 681
# 当前时间步: 682
# 当前时间步: 683
# 当前时间步: 684
# 当前时间步: 685
# 当前时间步: 686
# 当前时间步: 687
# 当前时间步: 688
# 当前时间步: 689
# 当前时间步: 690
# 当前时间步: 691
# 当前时间步: 692
# 当前时间步: 693
# 当前时间步: 694
# 当前时间步: 695
# 当前时间步: 696
# 当前时间步: 697
# 当前时间步: 698
# 当前时间步: 699
# 当前时间步: 700
# 当前时间步: 701
# 当前时间步: 702
# 当前时间步: 703
# 当前时间步: 704
# 当前时间步: 705
# 当前时间步: 706
# 当前时间步: 707
# 当前时间步: 708
# 当前时间步: 709
# 当前时间步: 710
# 当前时间步: 711
# 当前时间步: 712
# 当前时间步: 713
# 当前时间步: 714
# 当前时间步: 715
# 当前时间步: 716
# 当前时间步: 717
# 当前时间步: 718
# 当前时间步: 719
# 当前时间步: 720
# 当前时间步: 721
# 当前时间步: 722
# 当前时间步: 723
# 当前时间步: 724
# 当前时间步: 725
# 当前时间步: 726
# 当前时间步: 727
# 当前时间步: 728
# 当前时间步: 729
# 当前时间步: 730
# 当前时间步: 731
# 当前时间步: 732
# 当前时间步: 733
# 当前时间步: 734
# 当前时间步: 735
# 当前时间步: 736
# 当前时间步: 737
# 当前时间步: 738
# 当前时间步: 739
# 当前时间步: 740
# 当前时间步: 741
# 当前时间步: 742
# 当前时间步: 743
# 当前时间步: 744
# 当前时间步: 745
# 当前时间步: 746
# 当前时间步: 747
# 当前时间步: 748
# 当前时间步: 749
# 当前时间步: 750
# 当前时间步: 751
# 当前时间步: 752
# 当前时间步: 753
# 当前时间步: 754
# 当前时间步: 755
# 当前时间步: 756
# 当前时间步: 757
# 当前时间步: 758
# 当前时间步: 759
# 当前时间步: 760
# 当前时间步: 761
# 当前时间步: 762
# 当前时间步: 763
# 当前时间步: 764
# 当前时间步: 765
# 当前时间步: 766
# 当前时间步: 767
# 当前时间步: 768
# 当前时间步: 769
# 当前时间步: 770
# 当前时间步: 771
# 当前时间步: 772
# 当前时间步: 773
# 当前时间步: 774
# 当前时间步: 775
# 当前时间步: 776
# 当前时间步: 777
# 当前时间步: 778
# 当前时间步: 779
# 当前时间步: 780
# 当前时间步: 781
# 当前时间步: 782
# 当前时间步: 783
# 当前时间步: 784
# 当前时间步: 785
# 当前时间步: 786
# 当前时间步: 787
# 当前时间步: 788
# 当前时间步: 789
# 当前时间步: 790
# 当前时间步: 791
# 当前时间步: 792
# 当前时间步: 793
# 当前时间步: 794
# 当前时间步: 795
# 当前时间步: 796
# 当前时间步: 797
# 当前时间步: 798
# 当前时间步: 799
# 当前时间步: 800
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 24.1     |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 168      |
# |    time_elapsed    | 4        |
# |    total_timesteps | 800      |
# | train/             |          |
# |    actor_loss      | -3.77    |
# |    critic_loss     | 0.35     |
# |    ent_coef        | 0.81     |
# |    ent_coef_loss   | -0.347   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 699      |
# ---------------------------------
# 当前时间步: 801
# 当前时间步: 802
# 当前时间步: 803
# 当前时间步: 804
# 当前时间步: 805
# 当前时间步: 806
# 当前时间步: 807
# 当前时间步: 808
# 当前时间步: 809
# 当前时间步: 810
# 当前时间步: 811
# 当前时间步: 812
# 当前时间步: 813
# 当前时间步: 814
# 当前时间步: 815
# 当前时间步: 816
# 当前时间步: 817
# 当前时间步: 818
# 当前时间步: 819
# 当前时间步: 820
# 当前时间步: 821
# 当前时间步: 822
# 当前时间步: 823
# 当前时间步: 824
# 当前时间步: 825
# 当前时间步: 826
# 当前时间步: 827
# 当前时间步: 828
# 当前时间步: 829
# 当前时间步: 830
# 当前时间步: 831
# 当前时间步: 832
# 当前时间步: 833
# 当前时间步: 834
# 当前时间步: 835
# 当前时间步: 836
# 当前时间步: 837
# 当前时间步: 838
# 当前时间步: 839
# 当前时间步: 840
# 当前时间步: 841
# 当前时间步: 842
# 当前时间步: 843
# 当前时间步: 844
# 当前时间步: 845
# 当前时间步: 846
# 当前时间步: 847
# 当前时间步: 848
# 当前时间步: 849
# 当前时间步: 850
# 当前时间步: 851
# 当前时间步: 852
# 当前时间步: 853
# 当前时间步: 854
# 当前时间步: 855
# 当前时间步: 856
# 当前时间步: 857
# 当前时间步: 858
# 当前时间步: 859
# 当前时间步: 860
# 当前时间步: 861
# 当前时间步: 862
# 当前时间步: 863
# 当前时间步: 864
# 当前时间步: 865
# 当前时间步: 866
# 当前时间步: 867
# 当前时间步: 868
# 当前时间步: 869
# 当前时间步: 870
# 当前时间步: 871
# 当前时间步: 872
# 当前时间步: 873
# 当前时间步: 874
# 当前时间步: 875
# 当前时间步: 876
# 当前时间步: 877
# 当前时间步: 878
# 当前时间步: 879
# 当前时间步: 880
# 当前时间步: 881
# 当前时间步: 882
# 当前时间步: 883
# 当前时间步: 884
# 当前时间步: 885
# 当前时间步: 886
# 当前时间步: 887
# 当前时间步: 888
# 当前时间步: 889
# 当前时间步: 890
# 当前时间步: 891
# 当前时间步: 892
# 当前时间步: 893
# 当前时间步: 894
# 当前时间步: 895
# 当前时间步: 896
# 当前时间步: 897
# 当前时间步: 898
# 当前时间步: 899
# 当前时间步: 900
# 当前时间步: 901
# 当前时间步: 902
# 当前时间步: 903
# 当前时间步: 904
# 当前时间步: 905
# 当前时间步: 906
# 当前时间步: 907
# 当前时间步: 908
# 当前时间步: 909
# 当前时间步: 910
# 当前时间步: 911
# 当前时间步: 912
# 当前时间步: 913
# 当前时间步: 914
# 当前时间步: 915
# 当前时间步: 916
# 当前时间步: 917
# 当前时间步: 918
# 当前时间步: 919
# 当前时间步: 920
# 当前时间步: 921
# 当前时间步: 922
# 当前时间步: 923
# 当前时间步: 924
# 当前时间步: 925
# 当前时间步: 926
# 当前时间步: 927
# 当前时间步: 928
# 当前时间步: 929
# 当前时间步: 930
# 当前时间步: 931
# 当前时间步: 932
# 当前时间步: 933
# 当前时间步: 934
# 当前时间步: 935
# 当前时间步: 936
# 当前时间步: 937
# 当前时间步: 938
# 当前时间步: 939
# 当前时间步: 940
# 当前时间步: 941
# 当前时间步: 942
# 当前时间步: 943
# 当前时间步: 944
# 当前时间步: 945
# 当前时间步: 946
# 当前时间步: 947
# 当前时间步: 948
# 当前时间步: 949
# 当前时间步: 950
# 当前时间步: 951
# 当前时间步: 952
# 当前时间步: 953
# 当前时间步: 954
# 当前时间步: 955
# 当前时间步: 956
# 当前时间步: 957
# 当前时间步: 958
# 当前时间步: 959
# 当前时间步: 960
# 当前时间步: 961
# 当前时间步: 962
# 当前时间步: 963
# 当前时间步: 964
# 当前时间步: 965
# 当前时间步: 966
# 当前时间步: 967
# 当前时间步: 968
# 当前时间步: 969
# 当前时间步: 970
# 当前时间步: 971
# 当前时间步: 972
# 当前时间步: 973
# 当前时间步: 974
# 当前时间步: 975
# 当前时间步: 976
# 当前时间步: 977
# 当前时间步: 978
# 当前时间步: 979
# 当前时间步: 980
# 当前时间步: 981
# 当前时间步: 982
# 当前时间步: 983
# 当前时间步: 984
# 当前时间步: 985
# 当前时间步: 986
# 当前时间步: 987
# 当前时间步: 988
# 当前时间步: 989
# 当前时间步: 990
# 当前时间步: 991
# 当前时间步: 992
# 当前时间步: 993
# 当前时间步: 994
# 当前时间步: 995
# 当前时间步: 996
# 当前时间步: 997
# 当前时间步: 998
# 当前时间步: 999
# 当前时间步: 1000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 24.2     |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 163      |
# |    time_elapsed    | 6        |
# |    total_timesteps | 1000     |
# | train/             |          |
# |    actor_loss      | -4.46    |
# |    critic_loss     | 0.292    |
# |    ent_coef        | 0.763    |
# |    ent_coef_loss   | -0.455   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 899      |
# ---------------------------------
# 当前时间步: 1001
# 当前时间步: 1002
# 当前时间步: 1003
# 当前时间步: 1004
# 当前时间步: 1005
# 当前时间步: 1006
# 当前时间步: 1007
# 当前时间步: 1008
# 当前时间步: 1009
# 当前时间步: 1010
# 当前时间步: 1011
# 当前时间步: 1012
# 当前时间步: 1013
# 当前时间步: 1014
# 当前时间步: 1015
# 当前时间步: 1016
# 当前时间步: 1017
# 当前时间步: 1018
# 当前时间步: 1019
# 当前时间步: 1020
# 当前时间步: 1021
# 当前时间步: 1022
# 当前时间步: 1023
# 当前时间步: 1024
# 当前时间步: 1025
# 当前时间步: 1026
# 当前时间步: 1027
# 当前时间步: 1028
# 当前时间步: 1029
# 当前时间步: 1030
# 当前时间步: 1031
# 当前时间步: 1032
# 当前时间步: 1033
# 当前时间步: 1034
# 当前时间步: 1035
# 当前时间步: 1036
# 当前时间步: 1037
# 当前时间步: 1038
# 当前时间步: 1039
# 当前时间步: 1040
# 当前时间步: 1041
# 当前时间步: 1042
# 当前时间步: 1043
# 当前时间步: 1044
# 当前时间步: 1045
# 当前时间步: 1046
# 当前时间步: 1047
# 当前时间步: 1048
# 当前时间步: 1049
# 当前时间步: 1050
# 当前时间步: 1051
# 当前时间步: 1052
# 当前时间步: 1053
# 当前时间步: 1054
# 当前时间步: 1055
# 当前时间步: 1056
# 当前时间步: 1057
# 当前时间步: 1058
# 当前时间步: 1059
# 当前时间步: 1060
# 当前时间步: 1061
# 当前时间步: 1062
# 当前时间步: 1063
# 当前时间步: 1064
# 当前时间步: 1065
# 当前时间步: 1066
# 当前时间步: 1067
# 当前时间步: 1068
# 当前时间步: 1069
# 当前时间步: 1070
# 当前时间步: 1071
# 当前时间步: 1072
# 当前时间步: 1073
# 当前时间步: 1074
# 当前时间步: 1075
# 当前时间步: 1076
# 当前时间步: 1077
# 当前时间步: 1078
# 当前时间步: 1079
# 当前时间步: 1080
# 当前时间步: 1081
# 当前时间步: 1082
# 当前时间步: 1083
# 当前时间步: 1084
# 当前时间步: 1085
# 当前时间步: 1086
# 当前时间步: 1087
# 当前时间步: 1088
# 当前时间步: 1089
# 当前时间步: 1090
# 当前时间步: 1091
# 当前时间步: 1092
# 当前时间步: 1093
# 当前时间步: 1094
# 当前时间步: 1095
# 当前时间步: 1096
# 当前时间步: 1097
# 当前时间步: 1098
# 当前时间步: 1099
# 当前时间步: 1100
# 当前时间步: 1101
# 当前时间步: 1102
# 当前时间步: 1103
# 当前时间步: 1104
# 当前时间步: 1105
# 当前时间步: 1106
# 当前时间步: 1107
# 当前时间步: 1108
# 当前时间步: 1109
# 当前时间步: 1110
# 当前时间步: 1111
# 当前时间步: 1112
# 当前时间步: 1113
# 当前时间步: 1114
# 当前时间步: 1115
# 当前时间步: 1116
# 当前时间步: 1117
# 当前时间步: 1118
# 当前时间步: 1119
# 当前时间步: 1120
# 当前时间步: 1121
# 当前时间步: 1122
# 当前时间步: 1123
# 当前时间步: 1124
# 当前时间步: 1125
# 当前时间步: 1126
# 当前时间步: 1127
# 当前时间步: 1128
# 当前时间步: 1129
# 当前时间步: 1130
# 当前时间步: 1131
# 当前时间步: 1132
# 当前时间步: 1133
# 当前时间步: 1134
# 当前时间步: 1135
# 当前时间步: 1136
# 当前时间步: 1137
# 当前时间步: 1138
# 当前时间步: 1139
# 当前时间步: 1140
# 当前时间步: 1141
# 当前时间步: 1142
# 当前时间步: 1143
# 当前时间步: 1144
# 当前时间步: 1145
# 当前时间步: 1146
# 当前时间步: 1147
# 当前时间步: 1148
# 当前时间步: 1149
# 当前时间步: 1150
# 当前时间步: 1151
# 当前时间步: 1152
# 当前时间步: 1153
# 当前时间步: 1154
# 当前时间步: 1155
# 当前时间步: 1156
# 当前时间步: 1157
# 当前时间步: 1158
# 当前时间步: 1159
# 当前时间步: 1160
# 当前时间步: 1161
# 当前时间步: 1162
# 当前时间步: 1163
# 当前时间步: 1164
# 当前时间步: 1165
# 当前时间步: 1166
# 当前时间步: 1167
# 当前时间步: 1168
# 当前时间步: 1169
# 当前时间步: 1170
# 当前时间步: 1171
# 当前时间步: 1172
# 当前时间步: 1173
# 当前时间步: 1174
# 当前时间步: 1175
# 当前时间步: 1176
# 当前时间步: 1177
# 当前时间步: 1178
# 当前时间步: 1179
# 当前时间步: 1180
# 当前时间步: 1181
# 当前时间步: 1182
# 当前时间步: 1183
# 当前时间步: 1184
# 当前时间步: 1185
# 当前时间步: 1186
# 当前时间步: 1187
# 当前时间步: 1188
# 当前时间步: 1189
# 当前时间步: 1190
# 当前时间步: 1191
# 当前时间步: 1192
# 当前时间步: 1193
# 当前时间步: 1194
# 当前时间步: 1195
# 当前时间步: 1196
# 当前时间步: 1197
# 当前时间步: 1198
# 当前时间步: 1199
# 当前时间步: 1200
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 24.2     |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 162      |
# |    time_elapsed    | 7        |
# |    total_timesteps | 1200     |
# | train/             |          |
# |    actor_loss      | -4.93    |
# |    critic_loss     | 0.442    |
# |    ent_coef        | 0.719    |
# |    ent_coef_loss   | -0.549   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1099     |
# ---------------------------------
# 当前时间步: 1201
# 当前时间步: 1202
# 当前时间步: 1203
# 当前时间步: 1204
# 当前时间步: 1205
# 当前时间步: 1206
# 当前时间步: 1207
# 当前时间步: 1208
# 当前时间步: 1209
# 当前时间步: 1210
# 当前时间步: 1211
# 当前时间步: 1212
# 当前时间步: 1213
# 当前时间步: 1214
# 当前时间步: 1215
# 当前时间步: 1216
# 当前时间步: 1217
# 当前时间步: 1218
# 当前时间步: 1219
# 当前时间步: 1220
# 当前时间步: 1221
# 当前时间步: 1222
# 当前时间步: 1223
# 当前时间步: 1224
# 当前时间步: 1225
# 当前时间步: 1226
# 当前时间步: 1227
# 当前时间步: 1228
# 当前时间步: 1229
# 当前时间步: 1230
# 当前时间步: 1231
# 当前时间步: 1232
# 当前时间步: 1233
# 当前时间步: 1234
# 当前时间步: 1235
# 当前时间步: 1236
# 当前时间步: 1237
# 当前时间步: 1238
# 当前时间步: 1239
# 当前时间步: 1240
# 当前时间步: 1241
# 当前时间步: 1242
# 当前时间步: 1243
# 当前时间步: 1244
# 当前时间步: 1245
# 当前时间步: 1246
# 当前时间步: 1247
# 当前时间步: 1248
# 当前时间步: 1249
# 当前时间步: 1250
# 当前时间步: 1251
# 当前时间步: 1252
# 当前时间步: 1253
# 当前时间步: 1254
# 当前时间步: 1255
# 当前时间步: 1256
# 当前时间步: 1257
# 当前时间步: 1258
# 当前时间步: 1259
# 当前时间步: 1260
# 当前时间步: 1261
# 当前时间步: 1262
# 当前时间步: 1263
# 当前时间步: 1264
# 当前时间步: 1265
# 当前时间步: 1266
# 当前时间步: 1267
# 当前时间步: 1268
# 当前时间步: 1269
# 当前时间步: 1270
# 当前时间步: 1271
# 当前时间步: 1272
# 当前时间步: 1273
# 当前时间步: 1274
# 当前时间步: 1275
# 当前时间步: 1276
# 当前时间步: 1277
# 当前时间步: 1278
# 当前时间步: 1279
# 当前时间步: 1280
# 当前时间步: 1281
# 当前时间步: 1282
# 当前时间步: 1283
# 当前时间步: 1284
# 当前时间步: 1285
# 当前时间步: 1286
# 当前时间步: 1287
# 当前时间步: 1288
# 当前时间步: 1289
# 当前时间步: 1290
# 当前时间步: 1291
# 当前时间步: 1292
# 当前时间步: 1293
# 当前时间步: 1294
# 当前时间步: 1295
# 当前时间步: 1296
# 当前时间步: 1297
# 当前时间步: 1298
# 当前时间步: 1299
# 当前时间步: 1300
# 当前时间步: 1301
# 当前时间步: 1302
# 当前时间步: 1303
# 当前时间步: 1304
# 当前时间步: 1305
# 当前时间步: 1306
# 当前时间步: 1307
# 当前时间步: 1308
# 当前时间步: 1309
# 当前时间步: 1310
# 当前时间步: 1311
# 当前时间步: 1312
# 当前时间步: 1313
# 当前时间步: 1314
# 当前时间步: 1315
# 当前时间步: 1316
# 当前时间步: 1317
# 当前时间步: 1318
# 当前时间步: 1319
# 当前时间步: 1320
# 当前时间步: 1321
# 当前时间步: 1322
# 当前时间步: 1323
# 当前时间步: 1324
# 当前时间步: 1325
# 当前时间步: 1326
# 当前时间步: 1327
# 当前时间步: 1328
# 当前时间步: 1329
# 当前时间步: 1330
# 当前时间步: 1331
# 当前时间步: 1332
# 当前时间步: 1333
# 当前时间步: 1334
# 当前时间步: 1335
# 当前时间步: 1336
# 当前时间步: 1337
# 当前时间步: 1338
# 当前时间步: 1339
# 当前时间步: 1340
# 当前时间步: 1341
# 当前时间步: 1342
# 当前时间步: 1343
# 当前时间步: 1344
# 当前时间步: 1345
# 当前时间步: 1346
# 当前时间步: 1347
# 当前时间步: 1348
# 当前时间步: 1349
# 当前时间步: 1350
# 当前时间步: 1351
# 当前时间步: 1352
# 当前时间步: 1353
# 当前时间步: 1354
# 当前时间步: 1355
# 当前时间步: 1356
# 当前时间步: 1357
# 当前时间步: 1358
# 当前时间步: 1359
# 当前时间步: 1360
# 当前时间步: 1361
# 当前时间步: 1362
# 当前时间步: 1363
# 当前时间步: 1364
# 当前时间步: 1365
# 当前时间步: 1366
# 当前时间步: 1367
# 当前时间步: 1368
# 当前时间步: 1369
# 当前时间步: 1370
# 当前时间步: 1371
# 当前时间步: 1372
# 当前时间步: 1373
# 当前时间步: 1374
# 当前时间步: 1375
# 当前时间步: 1376
# 当前时间步: 1377
# 当前时间步: 1378
# 当前时间步: 1379
# 当前时间步: 1380
# 当前时间步: 1381
# 当前时间步: 1382
# 当前时间步: 1383
# 当前时间步: 1384
# 当前时间步: 1385
# 当前时间步: 1386
# 当前时间步: 1387
# 当前时间步: 1388
# 当前时间步: 1389
# 当前时间步: 1390
# 当前时间步: 1391
# 当前时间步: 1392
# 当前时间步: 1393
# 当前时间步: 1394
# 当前时间步: 1395
# 当前时间步: 1396
# 当前时间步: 1397
# 当前时间步: 1398
# 当前时间步: 1399
# 当前时间步: 1400
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 23.9     |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 161      |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1400     |
# | train/             |          |
# |    actor_loss      | -5.67    |
# |    critic_loss     | 0.526    |
# |    ent_coef        | 0.677    |
# |    ent_coef_loss   | -0.656   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1299     |
# ---------------------------------
# 当前时间步: 1401
# 当前时间步: 1402
# 当前时间步: 1403
# 当前时间步: 1404
# 当前时间步: 1405
# 当前时间步: 1406
# 当前时间步: 1407
# 当前时间步: 1408
# 当前时间步: 1409
# 当前时间步: 1410
# 当前时间步: 1411
# 当前时间步: 1412
# 当前时间步: 1413
# 当前时间步: 1414
# 当前时间步: 1415
# 当前时间步: 1416
# 当前时间步: 1417
# 当前时间步: 1418
# 当前时间步: 1419
# 当前时间步: 1420
# 当前时间步: 1421
# 当前时间步: 1422
# 当前时间步: 1423
# 当前时间步: 1424
# 当前时间步: 1425
# 当前时间步: 1426
# 当前时间步: 1427
# 当前时间步: 1428
# 当前时间步: 1429
# 当前时间步: 1430
# 当前时间步: 1431
# 当前时间步: 1432
# 当前时间步: 1433
# 当前时间步: 1434
# 当前时间步: 1435
# 当前时间步: 1436
# 当前时间步: 1437
# 当前时间步: 1438
# 当前时间步: 1439
# 当前时间步: 1440
# 当前时间步: 1441
# 当前时间步: 1442
# 当前时间步: 1443
# 当前时间步: 1444
# 当前时间步: 1445
# 当前时间步: 1446
# 当前时间步: 1447
# 当前时间步: 1448
# 当前时间步: 1449
# 当前时间步: 1450
# 当前时间步: 1451
# 当前时间步: 1452
# 当前时间步: 1453
# 当前时间步: 1454
# 当前时间步: 1455
# 当前时间步: 1456
# 当前时间步: 1457
# 当前时间步: 1458
# 当前时间步: 1459
# 当前时间步: 1460
# 当前时间步: 1461
# 当前时间步: 1462
# 当前时间步: 1463
# 当前时间步: 1464
# 当前时间步: 1465
# 当前时间步: 1466
# 当前时间步: 1467
# 当前时间步: 1468
# 当前时间步: 1469
# 当前时间步: 1470
# 当前时间步: 1471
# 当前时间步: 1472
# 当前时间步: 1473
# 当前时间步: 1474
# 当前时间步: 1475
# 当前时间步: 1476
# 当前时间步: 1477
# 当前时间步: 1478
# 当前时间步: 1479
# 当前时间步: 1480
# 当前时间步: 1481
# 当前时间步: 1482
# 当前时间步: 1483
# 当前时间步: 1484
# 当前时间步: 1485
# 当前时间步: 1486
# 当前时间步: 1487
# 当前时间步: 1488
# 当前时间步: 1489
# 当前时间步: 1490
# 当前时间步: 1491
# 当前时间步: 1492
# 当前时间步: 1493
# 当前时间步: 1494
# 当前时间步: 1495
# 当前时间步: 1496
# 当前时间步: 1497
# 当前时间步: 1498
# 当前时间步: 1499
# 当前时间步: 1500
# 当前时间步: 1501
# 当前时间步: 1502
# 当前时间步: 1503
# 当前时间步: 1504
# 当前时间步: 1505
# 当前时间步: 1506
# 当前时间步: 1507
# 当前时间步: 1508
# 当前时间步: 1509
# 当前时间步: 1510
# 当前时间步: 1511
# 当前时间步: 1512
# 当前时间步: 1513
# 当前时间步: 1514
# 当前时间步: 1515
# 当前时间步: 1516
# 当前时间步: 1517
# 当前时间步: 1518
# 当前时间步: 1519
# 当前时间步: 1520
# 当前时间步: 1521
# 当前时间步: 1522
# 当前时间步: 1523
# 当前时间步: 1524
# 当前时间步: 1525
# 当前时间步: 1526
# 当前时间步: 1527
# 当前时间步: 1528
# 当前时间步: 1529
# 当前时间步: 1530
# 当前时间步: 1531
# 当前时间步: 1532
# 当前时间步: 1533
# 当前时间步: 1534
# 当前时间步: 1535
# 当前时间步: 1536
# 当前时间步: 1537
# 当前时间步: 1538
# 当前时间步: 1539
# 当前时间步: 1540
# 当前时间步: 1541
# 当前时间步: 1542
# 当前时间步: 1543
# 当前时间步: 1544
# 当前时间步: 1545
# 当前时间步: 1546
# 当前时间步: 1547
# 当前时间步: 1548
# 当前时间步: 1549
# 当前时间步: 1550
# 当前时间步: 1551
# 当前时间步: 1552
# 当前时间步: 1553
# 当前时间步: 1554
# 当前时间步: 1555
# 当前时间步: 1556
# 当前时间步: 1557
# 当前时间步: 1558
# 当前时间步: 1559
# 当前时间步: 1560
# 当前时间步: 1561
# 当前时间步: 1562
# 当前时间步: 1563
# 当前时间步: 1564
# 当前时间步: 1565
# 当前时间步: 1566
# 当前时间步: 1567
# 当前时间步: 1568
# 当前时间步: 1569
# 当前时间步: 1570
# 当前时间步: 1571
# 当前时间步: 1572
# 当前时间步: 1573
# 当前时间步: 1574
# 当前时间步: 1575
# 当前时间步: 1576
# 当前时间步: 1577
# 当前时间步: 1578
# 当前时间步: 1579
# 当前时间步: 1580
# 当前时间步: 1581
# 当前时间步: 1582
# 当前时间步: 1583
# 当前时间步: 1584
# 当前时间步: 1585
# 当前时间步: 1586
# 当前时间步: 1587
# 当前时间步: 1588
# 当前时间步: 1589
# 当前时间步: 1590
# 当前时间步: 1591
# 当前时间步: 1592
# 当前时间步: 1593
# 当前时间步: 1594
# 当前时间步: 1595
# 当前时间步: 1596
# 当前时间步: 1597
# 当前时间步: 1598
# 当前时间步: 1599
# 当前时间步: 1600
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 23.6     |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 160      |
# |    time_elapsed    | 9        |
# |    total_timesteps | 1600     |
# | train/             |          |
# |    actor_loss      | -6.29    |
# |    critic_loss     | 0.484    |
# |    ent_coef        | 0.637    |
# |    ent_coef_loss   | -0.747   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1499     |
# ---------------------------------
# 当前时间步: 1601
# 当前时间步: 1602
# 当前时间步: 1603
# 当前时间步: 1604
# 当前时间步: 1605
# 当前时间步: 1606
# 当前时间步: 1607
# 当前时间步: 1608
# 当前时间步: 1609
# 当前时间步: 1610
# 当前时间步: 1611
# 当前时间步: 1612
# 当前时间步: 1613
# 当前时间步: 1614
# 当前时间步: 1615
# 当前时间步: 1616
# 当前时间步: 1617
# 当前时间步: 1618
# 当前时间步: 1619
# 当前时间步: 1620
# 当前时间步: 1621
# 当前时间步: 1622
# 当前时间步: 1623
# 当前时间步: 1624
# 当前时间步: 1625
# 当前时间步: 1626
# 当前时间步: 1627
# 当前时间步: 1628
# 当前时间步: 1629
# 当前时间步: 1630
# 当前时间步: 1631
# 当前时间步: 1632
# 当前时间步: 1633
# 当前时间步: 1634
# 当前时间步: 1635
# 当前时间步: 1636
# 当前时间步: 1637
# 当前时间步: 1638
# 当前时间步: 1639
# 当前时间步: 1640
# 当前时间步: 1641
# 当前时间步: 1642
# 当前时间步: 1643
# 当前时间步: 1644
# 当前时间步: 1645
# 当前时间步: 1646
# 当前时间步: 1647
# 当前时间步: 1648
# 当前时间步: 1649
# 当前时间步: 1650
# 当前时间步: 1651
# 当前时间步: 1652
# 当前时间步: 1653
# 当前时间步: 1654
# 当前时间步: 1655
# 当前时间步: 1656
# 当前时间步: 1657
# 当前时间步: 1658
# 当前时间步: 1659
# 当前时间步: 1660
# 当前时间步: 1661
# 当前时间步: 1662
# 当前时间步: 1663
# 当前时间步: 1664
# 当前时间步: 1665
# 当前时间步: 1666
# 当前时间步: 1667
# 当前时间步: 1668
# 当前时间步: 1669
# 当前时间步: 1670
# 当前时间步: 1671
# 当前时间步: 1672
# 当前时间步: 1673
# 当前时间步: 1674
# 当前时间步: 1675
# 当前时间步: 1676
# 当前时间步: 1677
# 当前时间步: 1678
# 当前时间步: 1679
# 当前时间步: 1680
# 当前时间步: 1681
# 当前时间步: 1682
# 当前时间步: 1683
# 当前时间步: 1684
# 当前时间步: 1685
# 当前时间步: 1686
# 当前时间步: 1687
# 当前时间步: 1688
# 当前时间步: 1689
# 当前时间步: 1690
# 当前时间步: 1691
# 当前时间步: 1692
# 当前时间步: 1693
# 当前时间步: 1694
# 当前时间步: 1695
# 当前时间步: 1696
# 当前时间步: 1697
# 当前时间步: 1698
# 当前时间步: 1699
# 当前时间步: 1700
# 当前时间步: 1701
# 当前时间步: 1702
# 当前时间步: 1703
# 当前时间步: 1704
# 当前时间步: 1705
# 当前时间步: 1706
# 当前时间步: 1707
# 当前时间步: 1708
# 当前时间步: 1709
# 当前时间步: 1710
# 当前时间步: 1711
# 当前时间步: 1712
# 当前时间步: 1713
# 当前时间步: 1714
# 当前时间步: 1715
# 当前时间步: 1716
# 当前时间步: 1717
# 当前时间步: 1718
# 当前时间步: 1719
# 当前时间步: 1720
# 当前时间步: 1721
# 当前时间步: 1722
# 当前时间步: 1723
# 当前时间步: 1724
# 当前时间步: 1725
# 当前时间步: 1726
# 当前时间步: 1727
# 当前时间步: 1728
# 当前时间步: 1729
# 当前时间步: 1730
# 当前时间步: 1731
# 当前时间步: 1732
# 当前时间步: 1733
# 当前时间步: 1734
# 当前时间步: 1735
# 当前时间步: 1736
# 当前时间步: 1737
# 当前时间步: 1738
# 当前时间步: 1739
# 当前时间步: 1740
# 当前时间步: 1741
# 当前时间步: 1742
# 当前时间步: 1743
# 当前时间步: 1744
# 当前时间步: 1745
# 当前时间步: 1746
# 当前时间步: 1747
# 当前时间步: 1748
# 当前时间步: 1749
# 当前时间步: 1750
# 当前时间步: 1751
# 当前时间步: 1752
# 当前时间步: 1753
# 当前时间步: 1754
# 当前时间步: 1755
# 当前时间步: 1756
# 当前时间步: 1757
# 当前时间步: 1758
# 当前时间步: 1759
# 当前时间步: 1760
# 当前时间步: 1761
# 当前时间步: 1762
# 当前时间步: 1763
# 当前时间步: 1764
# 当前时间步: 1765
# 当前时间步: 1766
# 当前时间步: 1767
# 当前时间步: 1768
# 当前时间步: 1769
# 当前时间步: 1770
# 当前时间步: 1771
# 当前时间步: 1772
# 当前时间步: 1773
# 当前时间步: 1774
# 当前时间步: 1775
# 当前时间步: 1776
# 当前时间步: 1777
# 当前时间步: 1778
# 当前时间步: 1779
# 当前时间步: 1780
# 当前时间步: 1781
# 当前时间步: 1782
# 当前时间步: 1783
# 当前时间步: 1784
# 当前时间步: 1785
# 当前时间步: 1786
# 当前时间步: 1787
# 当前时间步: 1788
# 当前时间步: 1789
# 当前时间步: 1790
# 当前时间步: 1791
# 当前时间步: 1792
# 当前时间步: 1793
# 当前时间步: 1794
# 当前时间步: 1795
# 当前时间步: 1796
# 当前时间步: 1797
# 当前时间步: 1798
# 当前时间步: 1799
# 当前时间步: 1800
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 23.6     |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 158      |
# |    time_elapsed    | 11       |
# |    total_timesteps | 1800     |
# | train/             |          |
# |    actor_loss      | -6.87    |
# |    critic_loss     | 0.739    |
# |    ent_coef        | 0.6      |
# |    ent_coef_loss   | -0.84    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1699     |
# ---------------------------------
# 当前时间步: 1801
# 当前时间步: 1802
# 当前时间步: 1803
# 当前时间步: 1804
# 当前时间步: 1805
# 当前时间步: 1806
# 当前时间步: 1807
# 当前时间步: 1808
# 当前时间步: 1809
# 当前时间步: 1810
# 当前时间步: 1811
# 当前时间步: 1812
# 当前时间步: 1813
# 当前时间步: 1814
# 当前时间步: 1815
# 当前时间步: 1816
# 当前时间步: 1817
# 当前时间步: 1818
# 当前时间步: 1819
# 当前时间步: 1820
# 当前时间步: 1821
# 当前时间步: 1822
# 当前时间步: 1823
# 当前时间步: 1824
# 当前时间步: 1825
# 当前时间步: 1826
# 当前时间步: 1827
# 当前时间步: 1828
# 当前时间步: 1829
# 当前时间步: 1830
# 当前时间步: 1831
# 当前时间步: 1832
# 当前时间步: 1833
# 当前时间步: 1834
# 当前时间步: 1835
# 当前时间步: 1836
# 当前时间步: 1837
# 当前时间步: 1838
# 当前时间步: 1839
# 当前时间步: 1840
# 当前时间步: 1841
# 当前时间步: 1842
# 当前时间步: 1843
# 当前时间步: 1844
# 当前时间步: 1845
# 当前时间步: 1846
# 当前时间步: 1847
# 当前时间步: 1848
# 当前时间步: 1849
# 当前时间步: 1850
# 当前时间步: 1851
# 当前时间步: 1852
# 当前时间步: 1853
# 当前时间步: 1854
# 当前时间步: 1855
# 当前时间步: 1856
# 当前时间步: 1857
# 当前时间步: 1858
# 当前时间步: 1859
# 当前时间步: 1860
# 当前时间步: 1861
# 当前时间步: 1862
# 当前时间步: 1863
# 当前时间步: 1864
# 当前时间步: 1865
# 当前时间步: 1866
# 当前时间步: 1867
# 当前时间步: 1868
# 当前时间步: 1869
# 当前时间步: 1870
# 当前时间步: 1871
# 当前时间步: 1872
# 当前时间步: 1873
# 当前时间步: 1874
# 当前时间步: 1875
# 当前时间步: 1876
# 当前时间步: 1877
# 当前时间步: 1878
# 当前时间步: 1879
# 当前时间步: 1880
# 当前时间步: 1881
# 当前时间步: 1882
# 当前时间步: 1883
# 当前时间步: 1884
# 当前时间步: 1885
# 当前时间步: 1886
# 当前时间步: 1887
# 当前时间步: 1888
# 当前时间步: 1889
# 当前时间步: 1890
# 当前时间步: 1891
# 当前时间步: 1892
# 当前时间步: 1893
# 当前时间步: 1894
# 当前时间步: 1895
# 当前时间步: 1896
# 当前时间步: 1897
# 当前时间步: 1898
# 当前时间步: 1899
# 当前时间步: 1900
# 当前时间步: 1901
# 当前时间步: 1902
# 当前时间步: 1903
# 当前时间步: 1904
# 当前时间步: 1905
# 当前时间步: 1906
# 当前时间步: 1907
# 当前时间步: 1908
# 当前时间步: 1909
# 当前时间步: 1910
# 当前时间步: 1911
# 当前时间步: 1912
# 当前时间步: 1913
# 当前时间步: 1914
# 当前时间步: 1915
# 当前时间步: 1916
# 当前时间步: 1917
# 当前时间步: 1918
# 当前时间步: 1919
# 当前时间步: 1920
# 当前时间步: 1921
# 当前时间步: 1922
# 当前时间步: 1923
# 当前时间步: 1924
# 当前时间步: 1925
# 当前时间步: 1926
# 当前时间步: 1927
# 当前时间步: 1928
# 当前时间步: 1929
# 当前时间步: 1930
# 当前时间步: 1931
# 当前时间步: 1932
# 当前时间步: 1933
# 当前时间步: 1934
# 当前时间步: 1935
# 当前时间步: 1936
# 当前时间步: 1937
# 当前时间步: 1938
# 当前时间步: 1939
# 当前时间步: 1940
# 当前时间步: 1941
# 当前时间步: 1942
# 当前时间步: 1943
# 当前时间步: 1944
# 当前时间步: 1945
# 当前时间步: 1946
# 当前时间步: 1947
# 当前时间步: 1948
# 当前时间步: 1949
# 当前时间步: 1950
# 当前时间步: 1951
# 当前时间步: 1952
# 当前时间步: 1953
# 当前时间步: 1954
# 当前时间步: 1955
# 当前时间步: 1956
# 当前时间步: 1957
# 当前时间步: 1958
# 当前时间步: 1959
# 当前时间步: 1960
# 当前时间步: 1961
# 当前时间步: 1962
# 当前时间步: 1963
# 当前时间步: 1964
# 当前时间步: 1965
# 当前时间步: 1966
# 当前时间步: 1967
# 当前时间步: 1968
# 当前时间步: 1969
# 当前时间步: 1970
# 当前时间步: 1971
# 当前时间步: 1972
# 当前时间步: 1973
# 当前时间步: 1974
# 当前时间步: 1975
# 当前时间步: 1976
# 当前时间步: 1977
# 当前时间步: 1978
# 当前时间步: 1979
# 当前时间步: 1980
# 当前时间步: 1981
# 当前时间步: 1982
# 当前时间步: 1983
# 当前时间步: 1984
# 当前时间步: 1985
# 当前时间步: 1986
# 当前时间步: 1987
# 当前时间步: 1988
# 当前时间步: 1989
# 当前时间步: 1990
# 当前时间步: 1991
# 当前时间步: 1992
# 当前时间步: 1993
# 当前时间步: 1994
# 当前时间步: 1995
# 当前时间步: 1996
# 当前时间步: 1997
# 当前时间步: 1998
# 当前时间步: 1999
# 当前时间步: 2000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 23.6     |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 157      |
# |    time_elapsed    | 12       |
# |    total_timesteps | 2000     |
# | train/             |          |
# |    actor_loss      | -7.71    |
# |    critic_loss     | 0.607    |
# |    ent_coef        | 0.565    |
# |    ent_coef_loss   | -0.931   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1899     |
# ---------------------------------
# 当前时间步: 2001
# 当前时间步: 2002
# 当前时间步: 2003
# 当前时间步: 2004
# 当前时间步: 2005
# 当前时间步: 2006
# 当前时间步: 2007
# 当前时间步: 2008
# 当前时间步: 2009
# 当前时间步: 2010
# 当前时间步: 2011
# 当前时间步: 2012
# 当前时间步: 2013
# 当前时间步: 2014
# 当前时间步: 2015
# 当前时间步: 2016
# 当前时间步: 2017
# 当前时间步: 2018
# 当前时间步: 2019
# 当前时间步: 2020
# 当前时间步: 2021
# 当前时间步: 2022
# 当前时间步: 2023
# 当前时间步: 2024
# 当前时间步: 2025
# 当前时间步: 2026
# 当前时间步: 2027
# 当前时间步: 2028
# 当前时间步: 2029
# 当前时间步: 2030
# 当前时间步: 2031
# 当前时间步: 2032
# 当前时间步: 2033
# 当前时间步: 2034
# 当前时间步: 2035
# 当前时间步: 2036
# 当前时间步: 2037
# 当前时间步: 2038
# 当前时间步: 2039
# 当前时间步: 2040
# 当前时间步: 2041
# 当前时间步: 2042
# 当前时间步: 2043
# 当前时间步: 2044
# 当前时间步: 2045
# 当前时间步: 2046
# 当前时间步: 2047
# 当前时间步: 2048
# 当前时间步: 2049
# 当前时间步: 2050
# 当前时间步: 2051
# 当前时间步: 2052
# 当前时间步: 2053
# 当前时间步: 2054
# 当前时间步: 2055
# 当前时间步: 2056
# 当前时间步: 2057
# 当前时间步: 2058
# 当前时间步: 2059
# 当前时间步: 2060
# 当前时间步: 2061
# 当前时间步: 2062
# 当前时间步: 2063
# 当前时间步: 2064
# 当前时间步: 2065
# 当前时间步: 2066
# 当前时间步: 2067
# 当前时间步: 2068
# 当前时间步: 2069
# 当前时间步: 2070
# 当前时间步: 2071
# 当前时间步: 2072
# 当前时间步: 2073
# 当前时间步: 2074
# 当前时间步: 2075
# 当前时间步: 2076
# 当前时间步: 2077
# 当前时间步: 2078
# 当前时间步: 2079
# 当前时间步: 2080
# 当前时间步: 2081
# 当前时间步: 2082
# 当前时间步: 2083
# 当前时间步: 2084
# 当前时间步: 2085
# 当前时间步: 2086
# 当前时间步: 2087
# 当前时间步: 2088
# 当前时间步: 2089
# 当前时间步: 2090
# 当前时间步: 2091
# 当前时间步: 2092
# 当前时间步: 2093
# 当前时间步: 2094
# 当前时间步: 2095
# 当前时间步: 2096
# 当前时间步: 2097
# 当前时间步: 2098
# 当前时间步: 2099
# 当前时间步: 2100
# 当前时间步: 2101
# 当前时间步: 2102
# 当前时间步: 2103
# 当前时间步: 2104
# 当前时间步: 2105
# 当前时间步: 2106
# 当前时间步: 2107
# 当前时间步: 2108
# 当前时间步: 2109
# 当前时间步: 2110
# 当前时间步: 2111
# 当前时间步: 2112
# 当前时间步: 2113
# 当前时间步: 2114
# 当前时间步: 2115
# 当前时间步: 2116
# 当前时间步: 2117
# 当前时间步: 2118
# 当前时间步: 2119
# 当前时间步: 2120
# 当前时间步: 2121
# 当前时间步: 2122
# 当前时间步: 2123
# 当前时间步: 2124
# 当前时间步: 2125
# 当前时间步: 2126
# 当前时间步: 2127
# 当前时间步: 2128
# 当前时间步: 2129
# 当前时间步: 2130
# 当前时间步: 2131
# 当前时间步: 2132
# 当前时间步: 2133
# 当前时间步: 2134
# 当前时间步: 2135
# 当前时间步: 2136
# 当前时间步: 2137
# 当前时间步: 2138
# 当前时间步: 2139
# 当前时间步: 2140
# 当前时间步: 2141
# 当前时间步: 2142
# 当前时间步: 2143
# 当前时间步: 2144
# 当前时间步: 2145
# 当前时间步: 2146
# 当前时间步: 2147
# 当前时间步: 2148
# 当前时间步: 2149
# 当前时间步: 2150
# 当前时间步: 2151
# 当前时间步: 2152
# 当前时间步: 2153
# 当前时间步: 2154
# 当前时间步: 2155
# 当前时间步: 2156
# 当前时间步: 2157
# 当前时间步: 2158
# 当前时间步: 2159
# 当前时间步: 2160
# 当前时间步: 2161
# 当前时间步: 2162
# 当前时间步: 2163
# 当前时间步: 2164
# 当前时间步: 2165
# 当前时间步: 2166
# 当前时间步: 2167
# 当前时间步: 2168
# 当前时间步: 2169
# 当前时间步: 2170
# 当前时间步: 2171
# 当前时间步: 2172
# 当前时间步: 2173
# 当前时间步: 2174
# 当前时间步: 2175
# 当前时间步: 2176
# 当前时间步: 2177
# 当前时间步: 2178
# 当前时间步: 2179
# 当前时间步: 2180
# 当前时间步: 2181
# 当前时间步: 2182
# 当前时间步: 2183
# 当前时间步: 2184
# 当前时间步: 2185
# 当前时间步: 2186
# 当前时间步: 2187
# 当前时间步: 2188
# 当前时间步: 2189
# 当前时间步: 2190
# 当前时间步: 2191
# 当前时间步: 2192
# 当前时间步: 2193
# 当前时间步: 2194
# 当前时间步: 2195
# 当前时间步: 2196
# 当前时间步: 2197
# 当前时间步: 2198
# 当前时间步: 2199
# 当前时间步: 2200
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 23.2     |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 152      |
# |    time_elapsed    | 14       |
# |    total_timesteps | 2200     |
# | train/             |          |
# |    actor_loss      | -7.74    |
# |    critic_loss     | 0.732    |
# |    ent_coef        | 0.533    |
# |    ent_coef_loss   | -1.04    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2099     |
# ---------------------------------
# 当前时间步: 2201
# 当前时间步: 2202
# 当前时间步: 2203
# 当前时间步: 2204
# 当前时间步: 2205
# 当前时间步: 2206
# 当前时间步: 2207
# 当前时间步: 2208
# 当前时间步: 2209
# 当前时间步: 2210
# 当前时间步: 2211
# 当前时间步: 2212
# 当前时间步: 2213
# 当前时间步: 2214
# 当前时间步: 2215
# 当前时间步: 2216
# 当前时间步: 2217
# 当前时间步: 2218
# 当前时间步: 2219
# 当前时间步: 2220
# 当前时间步: 2221
# 当前时间步: 2222
# 当前时间步: 2223
# 当前时间步: 2224
# 当前时间步: 2225
# 当前时间步: 2226
# 当前时间步: 2227
# 当前时间步: 2228
# 当前时间步: 2229
# 当前时间步: 2230
# 当前时间步: 2231
# 当前时间步: 2232
# 当前时间步: 2233
# 当前时间步: 2234
# 当前时间步: 2235
# 当前时间步: 2236
# 当前时间步: 2237
# 当前时间步: 2238
# 当前时间步: 2239
# 当前时间步: 2240
# 当前时间步: 2241
# 当前时间步: 2242
# 当前时间步: 2243
# 当前时间步: 2244
# 当前时间步: 2245
# 当前时间步: 2246
# 当前时间步: 2247
# 当前时间步: 2248
# 当前时间步: 2249
# 当前时间步: 2250
# 当前时间步: 2251
# 当前时间步: 2252
# 当前时间步: 2253
# 当前时间步: 2254
# 当前时间步: 2255
# 当前时间步: 2256
# 当前时间步: 2257
# 当前时间步: 2258
# 当前时间步: 2259
# 当前时间步: 2260
# 当前时间步: 2261
# 当前时间步: 2262
# 当前时间步: 2263
# 当前时间步: 2264
# 当前时间步: 2265
# 当前时间步: 2266
# 当前时间步: 2267
# 当前时间步: 2268
# 当前时间步: 2269
# 当前时间步: 2270
# 当前时间步: 2271
# 当前时间步: 2272
# 当前时间步: 2273
# 当前时间步: 2274
# 当前时间步: 2275
# 当前时间步: 2276
# 当前时间步: 2277
# 当前时间步: 2278
# 当前时间步: 2279
# 当前时间步: 2280
# 当前时间步: 2281
# 当前时间步: 2282
# 当前时间步: 2283
# 当前时间步: 2284
# 当前时间步: 2285
# 当前时间步: 2286
# 当前时间步: 2287
# 当前时间步: 2288
# 当前时间步: 2289
# 当前时间步: 2290
# 当前时间步: 2291
# 当前时间步: 2292
# 当前时间步: 2293
# 当前时间步: 2294
# 当前时间步: 2295
# 当前时间步: 2296
# 当前时间步: 2297
# 当前时间步: 2298
# 当前时间步: 2299
# 当前时间步: 2300
# 当前时间步: 2301
# 当前时间步: 2302
# 当前时间步: 2303
# 当前时间步: 2304
# 当前时间步: 2305
# 当前时间步: 2306
# 当前时间步: 2307
# 当前时间步: 2308
# 当前时间步: 2309
# 当前时间步: 2310
# 当前时间步: 2311
# 当前时间步: 2312
# 当前时间步: 2313
# 当前时间步: 2314
# 当前时间步: 2315
# 当前时间步: 2316
# 当前时间步: 2317
# 当前时间步: 2318
# 当前时间步: 2319
# 当前时间步: 2320
# 当前时间步: 2321
# 当前时间步: 2322
# 当前时间步: 2323
# 当前时间步: 2324
# 当前时间步: 2325
# 当前时间步: 2326
# 当前时间步: 2327
# 当前时间步: 2328
# 当前时间步: 2329
# 当前时间步: 2330
# 当前时间步: 2331
# 当前时间步: 2332
# 当前时间步: 2333
# 当前时间步: 2334
# 当前时间步: 2335
# 当前时间步: 2336
# 当前时间步: 2337
# 当前时间步: 2338
# 当前时间步: 2339
# 当前时间步: 2340
# 当前时间步: 2341
# 当前时间步: 2342
# 当前时间步: 2343
# 当前时间步: 2344
# 当前时间步: 2345
# 当前时间步: 2346
# 当前时间步: 2347
# 当前时间步: 2348
# 当前时间步: 2349
# 当前时间步: 2350
# 当前时间步: 2351
# 当前时间步: 2352
# 当前时间步: 2353
# 当前时间步: 2354
# 当前时间步: 2355
# 当前时间步: 2356
# 当前时间步: 2357
# 当前时间步: 2358
# 当前时间步: 2359
# 当前时间步: 2360
# 当前时间步: 2361
# 当前时间步: 2362
# 当前时间步: 2363
# 当前时间步: 2364
# 当前时间步: 2365
# 当前时间步: 2366
# 当前时间步: 2367
# 当前时间步: 2368
# 当前时间步: 2369
# 当前时间步: 2370
# 当前时间步: 2371
# 当前时间步: 2372
# 当前时间步: 2373
# 当前时间步: 2374
# 当前时间步: 2375
# 当前时间步: 2376
# 当前时间步: 2377
# 当前时间步: 2378
# 当前时间步: 2379
# 当前时间步: 2380
# 当前时间步: 2381
# 当前时间步: 2382
# 当前时间步: 2383
# 当前时间步: 2384
# 当前时间步: 2385
# 当前时间步: 2386
# 当前时间步: 2387
# 当前时间步: 2388
# 当前时间步: 2389
# 当前时间步: 2390
# 当前时间步: 2391
# 当前时间步: 2392
# 当前时间步: 2393
# 当前时间步: 2394
# 当前时间步: 2395
# 当前时间步: 2396
# 当前时间步: 2397
# 当前时间步: 2398
# 当前时间步: 2399
# 当前时间步: 2400
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 23.6     |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 145      |
# |    time_elapsed    | 16       |
# |    total_timesteps | 2400     |
# | train/             |          |
# |    actor_loss      | -8.1     |
# |    critic_loss     | 1        |
# |    ent_coef        | 0.502    |
# |    ent_coef_loss   | -1.15    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2299     |
# ---------------------------------
# 当前时间步: 2401
# 当前时间步: 2402
# 当前时间步: 2403
# 当前时间步: 2404
# 当前时间步: 2405
# 当前时间步: 2406
# 当前时间步: 2407
# 当前时间步: 2408
# 当前时间步: 2409
# 当前时间步: 2410
# 当前时间步: 2411
# 当前时间步: 2412
# 当前时间步: 2413
# 当前时间步: 2414
# 当前时间步: 2415
# 当前时间步: 2416
# 当前时间步: 2417
# 当前时间步: 2418
# 当前时间步: 2419
# 当前时间步: 2420
# 当前时间步: 2421
# 当前时间步: 2422
# 当前时间步: 2423
# 当前时间步: 2424
# 当前时间步: 2425
# 当前时间步: 2426
# 当前时间步: 2427
# 当前时间步: 2428
# 当前时间步: 2429
# 当前时间步: 2430
# 当前时间步: 2431
# 当前时间步: 2432
# 当前时间步: 2433
# 当前时间步: 2434
# 当前时间步: 2435
# 当前时间步: 2436
# 当前时间步: 2437
# 当前时间步: 2438
# 当前时间步: 2439
# 当前时间步: 2440
# 当前时间步: 2441
# 当前时间步: 2442
# 当前时间步: 2443
# 当前时间步: 2444
# 当前时间步: 2445
# 当前时间步: 2446
# 当前时间步: 2447
# 当前时间步: 2448
# 当前时间步: 2449
# 当前时间步: 2450
# 当前时间步: 2451
# 当前时间步: 2452
# 当前时间步: 2453
# 当前时间步: 2454
# 当前时间步: 2455
# 当前时间步: 2456
# 当前时间步: 2457
# 当前时间步: 2458
# 当前时间步: 2459
# 当前时间步: 2460
# 当前时间步: 2461
# 当前时间步: 2462
# 当前时间步: 2463
# 当前时间步: 2464
# 当前时间步: 2465
# 当前时间步: 2466
# 当前时间步: 2467
# 当前时间步: 2468
# 当前时间步: 2469
# 当前时间步: 2470
# 当前时间步: 2471
# 当前时间步: 2472
# 当前时间步: 2473
# 当前时间步: 2474
# 当前时间步: 2475
# 当前时间步: 2476
# 当前时间步: 2477
# 当前时间步: 2478
# 当前时间步: 2479
# 当前时间步: 2480
# 当前时间步: 2481
# 当前时间步: 2482
# 当前时间步: 2483
# 当前时间步: 2484
# 当前时间步: 2485
# 当前时间步: 2486
# 当前时间步: 2487
# 当前时间步: 2488
# 当前时间步: 2489
# 当前时间步: 2490
# 当前时间步: 2491
# 当前时间步: 2492
# 当前时间步: 2493
# 当前时间步: 2494
# 当前时间步: 2495
# 当前时间步: 2496
# 当前时间步: 2497
# 当前时间步: 2498
# 当前时间步: 2499
# 当前时间步: 2500
# 当前时间步: 2501
# 当前时间步: 2502
# 当前时间步: 2503
# 当前时间步: 2504
# 当前时间步: 2505
# 当前时间步: 2506
# 当前时间步: 2507
# 当前时间步: 2508
# 当前时间步: 2509
# 当前时间步: 2510
# 当前时间步: 2511
# 当前时间步: 2512
# 当前时间步: 2513
# 当前时间步: 2514
# 当前时间步: 2515
# 当前时间步: 2516
# 当前时间步: 2517
# 当前时间步: 2518
# 当前时间步: 2519
# 当前时间步: 2520
# 当前时间步: 2521
# 当前时间步: 2522
# 当前时间步: 2523
# 当前时间步: 2524
# 当前时间步: 2525
# 当前时间步: 2526
# 当前时间步: 2527
# 当前时间步: 2528
# 当前时间步: 2529
# 当前时间步: 2530
# 当前时间步: 2531
# 当前时间步: 2532
# 当前时间步: 2533
# 当前时间步: 2534
# 当前时间步: 2535
# 当前时间步: 2536
# 当前时间步: 2537
# 当前时间步: 2538
# 当前时间步: 2539
# 当前时间步: 2540
# 当前时间步: 2541
# 当前时间步: 2542
# 当前时间步: 2543
# 当前时间步: 2544
# 当前时间步: 2545
# 当前时间步: 2546
# 当前时间步: 2547
# 当前时间步: 2548
# 当前时间步: 2549
# 当前时间步: 2550
# 当前时间步: 2551
# 当前时间步: 2552
# 当前时间步: 2553
# 当前时间步: 2554
# 当前时间步: 2555
# 当前时间步: 2556
# 当前时间步: 2557
# 当前时间步: 2558
# 当前时间步: 2559
# 当前时间步: 2560
# 当前时间步: 2561
# 当前时间步: 2562
# 当前时间步: 2563
# 当前时间步: 2564
# 当前时间步: 2565
# 当前时间步: 2566
# 当前时间步: 2567
# 当前时间步: 2568
# 当前时间步: 2569
# 当前时间步: 2570
# 当前时间步: 2571
# 当前时间步: 2572
# 当前时间步: 2573
# 当前时间步: 2574
# 当前时间步: 2575
# 当前时间步: 2576
# 当前时间步: 2577
# 当前时间步: 2578
# 当前时间步: 2579
# 当前时间步: 2580
# 当前时间步: 2581
# 当前时间步: 2582
# 当前时间步: 2583
# 当前时间步: 2584
# 当前时间步: 2585
# 当前时间步: 2586
# 当前时间步: 2587
# 当前时间步: 2588
# 当前时间步: 2589
# 当前时间步: 2590
# 当前时间步: 2591
# 当前时间步: 2592
# 当前时间步: 2593
# 当前时间步: 2594
# 当前时间步: 2595
# 当前时间步: 2596
# 当前时间步: 2597
# 当前时间步: 2598
# 当前时间步: 2599
# 当前时间步: 2600
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 23.6     |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 142      |
# |    time_elapsed    | 18       |
# |    total_timesteps | 2600     |
# | train/             |          |
# |    actor_loss      | -8.91    |
# |    critic_loss     | 0.834    |
# |    ent_coef        | 0.473    |
# |    ent_coef_loss   | -1.23    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2499     |
# ---------------------------------
# 当前时间步: 2601
# 当前时间步: 2602
# 当前时间步: 2603
# 当前时间步: 2604
# 当前时间步: 2605
# 当前时间步: 2606
# 当前时间步: 2607
# 当前时间步: 2608
# 当前时间步: 2609
# 当前时间步: 2610
# 当前时间步: 2611
# 当前时间步: 2612
# 当前时间步: 2613
# 当前时间步: 2614
# 当前时间步: 2615
# 当前时间步: 2616
# 当前时间步: 2617
# 当前时间步: 2618
# 当前时间步: 2619
# 当前时间步: 2620
# 当前时间步: 2621
# 当前时间步: 2622
# 当前时间步: 2623
# 当前时间步: 2624
# 当前时间步: 2625
# 当前时间步: 2626
# 当前时间步: 2627
# 当前时间步: 2628
# 当前时间步: 2629
# 当前时间步: 2630
# 当前时间步: 2631
# 当前时间步: 2632
# 当前时间步: 2633
# 当前时间步: 2634
# 当前时间步: 2635
# 当前时间步: 2636
# 当前时间步: 2637
# 当前时间步: 2638
# 当前时间步: 2639
# 当前时间步: 2640
# 当前时间步: 2641
# 当前时间步: 2642
# 当前时间步: 2643
# 当前时间步: 2644
# 当前时间步: 2645
# 当前时间步: 2646
# 当前时间步: 2647
# 当前时间步: 2648
# 当前时间步: 2649
# 当前时间步: 2650
# 当前时间步: 2651
# 当前时间步: 2652
# 当前时间步: 2653
# 当前时间步: 2654
# 当前时间步: 2655
# 当前时间步: 2656
# 当前时间步: 2657
# 当前时间步: 2658
# 当前时间步: 2659
# 当前时间步: 2660
# 当前时间步: 2661
# 当前时间步: 2662
# 当前时间步: 2663
# 当前时间步: 2664
# 当前时间步: 2665
# 当前时间步: 2666
# 当前时间步: 2667
# 当前时间步: 2668
# 当前时间步: 2669
# 当前时间步: 2670
# 当前时间步: 2671
# 当前时间步: 2672
# 当前时间步: 2673
# 当前时间步: 2674
# 当前时间步: 2675
# 当前时间步: 2676
# 当前时间步: 2677
# 当前时间步: 2678
# 当前时间步: 2679
# 当前时间步: 2680
# 当前时间步: 2681
# 当前时间步: 2682
# 当前时间步: 2683
# 当前时间步: 2684
# 当前时间步: 2685
# 当前时间步: 2686
# 当前时间步: 2687
# 当前时间步: 2688
# 当前时间步: 2689
# 当前时间步: 2690
# 当前时间步: 2691
# 当前时间步: 2692
# 当前时间步: 2693
# 当前时间步: 2694
# 当前时间步: 2695
# 当前时间步: 2696
# 当前时间步: 2697
# 当前时间步: 2698
# 当前时间步: 2699
# 当前时间步: 2700
# 当前时间步: 2701
# 当前时间步: 2702
# 当前时间步: 2703
# 当前时间步: 2704
# 当前时间步: 2705
# 当前时间步: 2706
# 当前时间步: 2707
# 当前时间步: 2708
# 当前时间步: 2709
# 当前时间步: 2710
# 当前时间步: 2711
# 当前时间步: 2712
# 当前时间步: 2713
# 当前时间步: 2714
# 当前时间步: 2715
# 当前时间步: 2716
# 当前时间步: 2717
# 当前时间步: 2718
# 当前时间步: 2719
# 当前时间步: 2720
# 当前时间步: 2721
# 当前时间步: 2722
# 当前时间步: 2723
# 当前时间步: 2724
# 当前时间步: 2725
# 当前时间步: 2726
# 当前时间步: 2727
# 当前时间步: 2728
# 当前时间步: 2729
# 当前时间步: 2730
# 当前时间步: 2731
# 当前时间步: 2732
# 当前时间步: 2733
# 当前时间步: 2734
# 当前时间步: 2735
# 当前时间步: 2736
# 当前时间步: 2737
# 当前时间步: 2738
# 当前时间步: 2739
# 当前时间步: 2740
# 当前时间步: 2741
# 当前时间步: 2742
# 当前时间步: 2743
# 当前时间步: 2744
# 当前时间步: 2745
# 当前时间步: 2746
# 当前时间步: 2747
# 当前时间步: 2748
# 当前时间步: 2749
# 当前时间步: 2750
# 当前时间步: 2751
# 当前时间步: 2752
# 当前时间步: 2753
# 当前时间步: 2754
# 当前时间步: 2755
# 当前时间步: 2756
# 当前时间步: 2757
# 当前时间步: 2758
# 当前时间步: 2759
# 当前时间步: 2760
# 当前时间步: 2761
# 当前时间步: 2762
# 当前时间步: 2763
# 当前时间步: 2764
# 当前时间步: 2765
# 当前时间步: 2766
# 当前时间步: 2767
# 当前时间步: 2768
# 当前时间步: 2769
# 当前时间步: 2770
# 当前时间步: 2771
# 当前时间步: 2772
# 当前时间步: 2773
# 当前时间步: 2774
# 当前时间步: 2775
# 当前时间步: 2776
# 当前时间步: 2777
# 当前时间步: 2778
# 当前时间步: 2779
# 当前时间步: 2780
# 当前时间步: 2781
# 当前时间步: 2782
# 当前时间步: 2783
# 当前时间步: 2784
# 当前时间步: 2785
# 当前时间步: 2786
# 当前时间步: 2787
# 当前时间步: 2788
# 当前时间步: 2789
# 当前时间步: 2790
# 当前时间步: 2791
# 当前时间步: 2792
# 当前时间步: 2793
# 当前时间步: 2794
# 当前时间步: 2795
# 当前时间步: 2796
# 当前时间步: 2797
# 当前时间步: 2798
# 当前时间步: 2799
# 当前时间步: 2800
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 23.6     |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 138      |
# |    time_elapsed    | 20       |
# |    total_timesteps | 2800     |
# | train/             |          |
# |    actor_loss      | -9.16    |
# |    critic_loss     | 0.54     |
# |    ent_coef        | 0.446    |
# |    ent_coef_loss   | -1.31    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2699     |
# ---------------------------------
# 当前时间步: 2801
# 当前时间步: 2802
# 当前时间步: 2803
# 当前时间步: 2804
# 当前时间步: 2805
# 当前时间步: 2806
# 当前时间步: 2807
# 当前时间步: 2808
# 当前时间步: 2809
# 当前时间步: 2810
# 当前时间步: 2811
# 当前时间步: 2812
# 当前时间步: 2813
# 当前时间步: 2814
# 当前时间步: 2815
# 当前时间步: 2816
# 当前时间步: 2817
# 当前时间步: 2818
# 当前时间步: 2819
# 当前时间步: 2820
# 当前时间步: 2821
# 当前时间步: 2822
# 当前时间步: 2823
# 当前时间步: 2824
# 当前时间步: 2825
# 当前时间步: 2826
# 当前时间步: 2827
# 当前时间步: 2828
# 当前时间步: 2829
# 当前时间步: 2830
# 当前时间步: 2831
# 当前时间步: 2832
# 当前时间步: 2833
# 当前时间步: 2834
# 当前时间步: 2835
# 当前时间步: 2836
# 当前时间步: 2837
# 当前时间步: 2838
# 当前时间步: 2839
# 当前时间步: 2840
# 当前时间步: 2841
# 当前时间步: 2842
# 当前时间步: 2843
# 当前时间步: 2844
# 当前时间步: 2845
# 当前时间步: 2846
# 当前时间步: 2847
# 当前时间步: 2848
# 当前时间步: 2849
# 当前时间步: 2850
# 当前时间步: 2851
# 当前时间步: 2852
# 当前时间步: 2853
# 当前时间步: 2854
# 当前时间步: 2855
# 当前时间步: 2856
# 当前时间步: 2857
# 当前时间步: 2858
# 当前时间步: 2859
# 当前时间步: 2860
# 当前时间步: 2861
# 当前时间步: 2862
# 当前时间步: 2863
# 当前时间步: 2864
# 当前时间步: 2865
# 当前时间步: 2866
# 当前时间步: 2867
# 当前时间步: 2868
# 当前时间步: 2869
# 当前时间步: 2870
# 当前时间步: 2871
# 当前时间步: 2872
# 当前时间步: 2873
# 当前时间步: 2874
# 当前时间步: 2875
# 当前时间步: 2876
# 当前时间步: 2877
# 当前时间步: 2878
# 当前时间步: 2879
# 当前时间步: 2880
# 当前时间步: 2881
# 当前时间步: 2882
# 当前时间步: 2883
# 当前时间步: 2884
# 当前时间步: 2885
# 当前时间步: 2886
# 当前时间步: 2887
# 当前时间步: 2888
# 当前时间步: 2889
# 当前时间步: 2890
# 当前时间步: 2891
# 当前时间步: 2892
# 当前时间步: 2893
# 当前时间步: 2894
# 当前时间步: 2895
# 当前时间步: 2896
# 当前时间步: 2897
# 当前时间步: 2898
# 当前时间步: 2899
# 当前时间步: 2900
# 当前时间步: 2901
# 当前时间步: 2902
# 当前时间步: 2903
# 当前时间步: 2904
# 当前时间步: 2905
# 当前时间步: 2906
# 当前时间步: 2907
# 当前时间步: 2908
# 当前时间步: 2909
# 当前时间步: 2910
# 当前时间步: 2911
# 当前时间步: 2912
# 当前时间步: 2913
# 当前时间步: 2914
# 当前时间步: 2915
# 当前时间步: 2916
# 当前时间步: 2917
# 当前时间步: 2918
# 当前时间步: 2919
# 当前时间步: 2920
# 当前时间步: 2921
# 当前时间步: 2922
# 当前时间步: 2923
# 当前时间步: 2924
# 当前时间步: 2925
# 当前时间步: 2926
# 当前时间步: 2927
# 当前时间步: 2928
# 当前时间步: 2929
# 当前时间步: 2930
# 当前时间步: 2931
# 当前时间步: 2932
# 当前时间步: 2933
# 当前时间步: 2934
# 当前时间步: 2935
# 当前时间步: 2936
# 当前时间步: 2937
# 当前时间步: 2938
# 当前时间步: 2939
# 当前时间步: 2940
# 当前时间步: 2941
# 当前时间步: 2942
# 当前时间步: 2943
# 当前时间步: 2944
# 当前时间步: 2945
# 当前时间步: 2946
# 当前时间步: 2947
# 当前时间步: 2948
# 当前时间步: 2949
# 当前时间步: 2950
# 当前时间步: 2951
# 当前时间步: 2952
# 当前时间步: 2953
# 当前时间步: 2954
# 当前时间步: 2955
# 当前时间步: 2956
# 当前时间步: 2957
# 当前时间步: 2958
# 当前时间步: 2959
# 当前时间步: 2960
# 当前时间步: 2961
# 当前时间步: 2962
# 当前时间步: 2963
# 当前时间步: 2964
# 当前时间步: 2965
# 当前时间步: 2966
# 当前时间步: 2967
# 当前时间步: 2968
# 当前时间步: 2969
# 当前时间步: 2970
# 当前时间步: 2971
# 当前时间步: 2972
# 当前时间步: 2973
# 当前时间步: 2974
# 当前时间步: 2975
# 当前时间步: 2976
# 当前时间步: 2977
# 当前时间步: 2978
# 当前时间步: 2979
# 当前时间步: 2980
# 当前时间步: 2981
# 当前时间步: 2982
# 当前时间步: 2983
# 当前时间步: 2984
# 当前时间步: 2985
# 当前时间步: 2986
# 当前时间步: 2987
# 当前时间步: 2988
# 当前时间步: 2989
# 当前时间步: 2990
# 当前时间步: 2991
# 当前时间步: 2992
# 当前时间步: 2993
# 当前时间步: 2994
# 当前时间步: 2995
# 当前时间步: 2996
# 当前时间步: 2997
# 当前时间步: 2998
# 当前时间步: 2999
# 当前时间步: 3000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 23.5     |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 136      |
# |    time_elapsed    | 21       |
# |    total_timesteps | 3000     |
# | train/             |          |
# |    actor_loss      | -9.28    |
# |    critic_loss     | 0.949    |
# |    ent_coef        | 0.42     |
# |    ent_coef_loss   | -1.43    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2899     |
# ---------------------------------
# 当前时间步: 3001
# 当前时间步: 3002
# 当前时间步: 3003
# 当前时间步: 3004
# 当前时间步: 3005
# 当前时间步: 3006
# 当前时间步: 3007
# 当前时间步: 3008
# 当前时间步: 3009
# 当前时间步: 3010
# 当前时间步: 3011
# 当前时间步: 3012
# 当前时间步: 3013
# 当前时间步: 3014
# 当前时间步: 3015
# 当前时间步: 3016
# 当前时间步: 3017
# 当前时间步: 3018
# 当前时间步: 3019
# 当前时间步: 3020
# 当前时间步: 3021
# 当前时间步: 3022
# 当前时间步: 3023
# 当前时间步: 3024
# 当前时间步: 3025
# 当前时间步: 3026
# 当前时间步: 3027
# 当前时间步: 3028
# 当前时间步: 3029
# 当前时间步: 3030
# 当前时间步: 3031
# 当前时间步: 3032
# 当前时间步: 3033
# 当前时间步: 3034
# 当前时间步: 3035
# 当前时间步: 3036
# 当前时间步: 3037
# 当前时间步: 3038
# 当前时间步: 3039
# 当前时间步: 3040
# 当前时间步: 3041
# 当前时间步: 3042
# 当前时间步: 3043
# 当前时间步: 3044
# 当前时间步: 3045
# 当前时间步: 3046
# 当前时间步: 3047
# 当前时间步: 3048
# 当前时间步: 3049
# 当前时间步: 3050
# 当前时间步: 3051
# 当前时间步: 3052
# 当前时间步: 3053
# 当前时间步: 3054
# 当前时间步: 3055
# 当前时间步: 3056
# 当前时间步: 3057
# 当前时间步: 3058
# 当前时间步: 3059
# 当前时间步: 3060
# 当前时间步: 3061
# 当前时间步: 3062
# 当前时间步: 3063
# 当前时间步: 3064
# 当前时间步: 3065
# 当前时间步: 3066
# 当前时间步: 3067
# 当前时间步: 3068
# 当前时间步: 3069
# 当前时间步: 3070
# 当前时间步: 3071
# 当前时间步: 3072
# 当前时间步: 3073
# 当前时间步: 3074
# 当前时间步: 3075
# 当前时间步: 3076
# 当前时间步: 3077
# 当前时间步: 3078
# 当前时间步: 3079
# 当前时间步: 3080
# 当前时间步: 3081
# 当前时间步: 3082
# 当前时间步: 3083
# 当前时间步: 3084
# 当前时间步: 3085
# 当前时间步: 3086
# 当前时间步: 3087
# 当前时间步: 3088
# 当前时间步: 3089
# 当前时间步: 3090
# 当前时间步: 3091
# 当前时间步: 3092
# 当前时间步: 3093
# 当前时间步: 3094
# 当前时间步: 3095
# 当前时间步: 3096
# 当前时间步: 3097
# 当前时间步: 3098
# 当前时间步: 3099
# 当前时间步: 3100
# 当前时间步: 3101
# 当前时间步: 3102
# 当前时间步: 3103
# 当前时间步: 3104
# 当前时间步: 3105
# 当前时间步: 3106
# 当前时间步: 3107
# 当前时间步: 3108
# 当前时间步: 3109
# 当前时间步: 3110
# 当前时间步: 3111
# 当前时间步: 3112
# 当前时间步: 3113
# 当前时间步: 3114
# 当前时间步: 3115
# 当前时间步: 3116
# 当前时间步: 3117
# 当前时间步: 3118
# 当前时间步: 3119
# 当前时间步: 3120
# 当前时间步: 3121
# 当前时间步: 3122
# 当前时间步: 3123
# 当前时间步: 3124
# 当前时间步: 3125
# 当前时间步: 3126
# 当前时间步: 3127
# 当前时间步: 3128
# 当前时间步: 3129
# 当前时间步: 3130
# 当前时间步: 3131
# 当前时间步: 3132
# 当前时间步: 3133
# 当前时间步: 3134
# 当前时间步: 3135
# 当前时间步: 3136
# 当前时间步: 3137
# 当前时间步: 3138
# 当前时间步: 3139
# 当前时间步: 3140
# 当前时间步: 3141
# 当前时间步: 3142
# 当前时间步: 3143
# 当前时间步: 3144
# 当前时间步: 3145
# 当前时间步: 3146
# 当前时间步: 3147
# 当前时间步: 3148
# 当前时间步: 3149
# 当前时间步: 3150
# 当前时间步: 3151
# 当前时间步: 3152
# 当前时间步: 3153
# 当前时间步: 3154
# 当前时间步: 3155
# 当前时间步: 3156
# 当前时间步: 3157
# 当前时间步: 3158
# 当前时间步: 3159
# 当前时间步: 3160
# 当前时间步: 3161
# 当前时间步: 3162
# 当前时间步: 3163
# 当前时间步: 3164
# 当前时间步: 3165
# 当前时间步: 3166
# 当前时间步: 3167
# 当前时间步: 3168
# 当前时间步: 3169
# 当前时间步: 3170
# 当前时间步: 3171
# 当前时间步: 3172
# 当前时间步: 3173
# 当前时间步: 3174
# 当前时间步: 3175
# 当前时间步: 3176
# 当前时间步: 3177
# 当前时间步: 3178
# 当前时间步: 3179
# 当前时间步: 3180
# 当前时间步: 3181
# 当前时间步: 3182
# 当前时间步: 3183
# 当前时间步: 3184
# 当前时间步: 3185
# 当前时间步: 3186
# 当前时间步: 3187
# 当前时间步: 3188
# 当前时间步: 3189
# 当前时间步: 3190
# 当前时间步: 3191
# 当前时间步: 3192
# 当前时间步: 3193
# 当前时间步: 3194
# 当前时间步: 3195
# 当前时间步: 3196
# 当前时间步: 3197
# 当前时间步: 3198
# 当前时间步: 3199
# 当前时间步: 3200
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 23.3     |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 133      |
# |    time_elapsed    | 23       |
# |    total_timesteps | 3200     |
# | train/             |          |
# |    actor_loss      | -10.1    |
# |    critic_loss     | 0.604    |
# |    ent_coef        | 0.396    |
# |    ent_coef_loss   | -1.5     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3099     |
# ---------------------------------
# 当前时间步: 3201
# 当前时间步: 3202
# 当前时间步: 3203
# 当前时间步: 3204
# 当前时间步: 3205
# 当前时间步: 3206
# 当前时间步: 3207
# 当前时间步: 3208
# 当前时间步: 3209
# 当前时间步: 3210
# 当前时间步: 3211
# 当前时间步: 3212
# 当前时间步: 3213
# 当前时间步: 3214
# 当前时间步: 3215
# 当前时间步: 3216
# 当前时间步: 3217
# 当前时间步: 3218
# 当前时间步: 3219
# 当前时间步: 3220
# 当前时间步: 3221
# 当前时间步: 3222
# 当前时间步: 3223
# 当前时间步: 3224
# 当前时间步: 3225
# 当前时间步: 3226
# 当前时间步: 3227
# 当前时间步: 3228
# 当前时间步: 3229
# 当前时间步: 3230
# 当前时间步: 3231
# 当前时间步: 3232
# 当前时间步: 3233
# 当前时间步: 3234
# 当前时间步: 3235
# 当前时间步: 3236
# 当前时间步: 3237
# 当前时间步: 3238
# 当前时间步: 3239
# 当前时间步: 3240
# 当前时间步: 3241
# 当前时间步: 3242
# 当前时间步: 3243
# 当前时间步: 3244
# 当前时间步: 3245
# 当前时间步: 3246
# 当前时间步: 3247
# 当前时间步: 3248
# 当前时间步: 3249
# 当前时间步: 3250
# 当前时间步: 3251
# 当前时间步: 3252
# 当前时间步: 3253
# 当前时间步: 3254
# 当前时间步: 3255
# 当前时间步: 3256
# 当前时间步: 3257
# 当前时间步: 3258
# 当前时间步: 3259
# 当前时间步: 3260
# 当前时间步: 3261
# 当前时间步: 3262
# 当前时间步: 3263
# 当前时间步: 3264
# 当前时间步: 3265
# 当前时间步: 3266
# 当前时间步: 3267
# 当前时间步: 3268
# 当前时间步: 3269
# 当前时间步: 3270
# 当前时间步: 3271
# 当前时间步: 3272
# 当前时间步: 3273
# 当前时间步: 3274
# 当前时间步: 3275
# 当前时间步: 3276
# 当前时间步: 3277
# 当前时间步: 3278
# 当前时间步: 3279
# 当前时间步: 3280
# 当前时间步: 3281
# 当前时间步: 3282
# 当前时间步: 3283
# 当前时间步: 3284
# 当前时间步: 3285
# 当前时间步: 3286
# 当前时间步: 3287
# 当前时间步: 3288
# 当前时间步: 3289
# 当前时间步: 3290
# 当前时间步: 3291
# 当前时间步: 3292
# 当前时间步: 3293
# 当前时间步: 3294
# 当前时间步: 3295
# 当前时间步: 3296
# 当前时间步: 3297
# 当前时间步: 3298
# 当前时间步: 3299
# 当前时间步: 3300
# 当前时间步: 3301
# 当前时间步: 3302
# 当前时间步: 3303
# 当前时间步: 3304
# 当前时间步: 3305
# 当前时间步: 3306
# 当前时间步: 3307
# 当前时间步: 3308
# ...
# 当前时间步: 3957
# 当前时间步: 3958
# 当前时间步: 3959
# 当前时间步: 3960
# 当前时间步: 3961
# 当前时间步: 3962
# 当前时间步: 3963
# 当前时间步: 3964
# 当前时间步: 3965
# 当前时间步: 3966
# 当前时间步: 3967
# 当前时间步: 3968
# 当前时间步: 3969
# 当前时间步: 3970
# 当前时间步: 3971
# 当前时间步: 3972
# 当前时间步: 3973
# 当前时间步: 3974
# 当前时间步: 3975
# 当前时间步: 3976
# 当前时间步: 3977
# 当前时间步: 3978
# 当前时间步: 3979
# 当前时间步: 3980
# 当前时间步: 3981
# 当前时间步: 3982
# 当前时间步: 3983
# 当前时间步: 3984
# 当前时间步: 3985
# 当前时间步: 3986
# 当前时间步: 3987
# 当前时间步: 3988
# 当前时间步: 3989
# 当前时间步: 3990
# 当前时间步: 3991
# 当前时间步: 3992
# 当前时间步: 3993
# 当前时间步: 3994
# 当前时间步: 3995
# 当前时间步: 3996
# 当前时间步: 3997
# 当前时间步: 3998
# 当前时间步: 3999
# 当前时间步: 4000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 23.1     |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 126      |
# |    time_elapsed    | 31       |
# |    total_timesteps | 4000     |
# | train/             |          |
# |    actor_loss      | -10.7    |
# |    critic_loss     | 0.75     |
# |    ent_coef        | 0.312    |
# |    ent_coef_loss   | -1.77    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3899     |
# ---------------------------------
# 当前时间步: 4001
# 当前时间步: 4002
# 当前时间步: 4003
# 当前时间步: 4004
# 当前时间步: 4005
# 当前时间步: 4006
# 当前时间步: 4007
# 当前时间步: 4008
# 当前时间步: 4009
# 当前时间步: 4010
# 当前时间步: 4011
# 当前时间步: 4012
# 当前时间步: 4013
# 当前时间步: 4014
# 当前时间步: 4015
# 当前时间步: 4016
# 当前时间步: 4017
# 当前时间步: 4018
# 当前时间步: 4019
# 当前时间步: 4020
# 当前时间步: 4021
# 当前时间步: 4022
# 当前时间步: 4023
# 当前时间步: 4024
# 当前时间步: 4025
# 当前时间步: 4026
# 当前时间步: 4027
# 当前时间步: 4028
# 当前时间步: 4029
# 当前时间步: 4030
# 当前时间步: 4031
# 当前时间步: 4032
# 当前时间步: 4033
# 当前时间步: 4034
# 当前时间步: 4035
# 当前时间步: 4036
# 当前时间步: 4037
# 当前时间步: 4038
# 当前时间步: 4039
# 当前时间步: 4040
# 当前时间步: 4041
# 当前时间步: 4042
# 当前时间步: 4043
# 当前时间步: 4044
# 当前时间步: 4045
# 当前时间步: 4046
# 当前时间步: 4047
# 当前时间步: 4048
# 当前时间步: 4049
# 当前时间步: 4050
# 当前时间步: 4051
# 当前时间步: 4052
# 当前时间步: 4053
# 当前时间步: 4054
# 当前时间步: 4055
# 当前时间步: 4056
# 当前时间步: 4057
# 当前时间步: 4058
# 当前时间步: 4059
# 当前时间步: 4060
# 当前时间步: 4061
# 当前时间步: 4062
# 当前时间步: 4063
# 当前时间步: 4064
# 当前时间步: 4065
# 当前时间步: 4066
# 当前时间步: 4067
# 当前时间步: 4068
# 当前时间步: 4069
# 当前时间步: 4070
# 当前时间步: 4071
# 当前时间步: 4072
# 当前时间步: 4073
# 当前时间步: 4074
# 当前时间步: 4075
# 当前时间步: 4076
# 当前时间步: 4077
# 当前时间步: 4078
# 当前时间步: 4079
# 当前时间步: 4080
# 当前时间步: 4081
# 当前时间步: 4082
# 当前时间步: 4083
# 当前时间步: 4084
# 当前时间步: 4085
# 当前时间步: 4086
# 当前时间步: 4087
# 当前时间步: 4088
# 当前时间步: 4089
# 当前时间步: 4090
# 当前时间步: 4091
# 当前时间步: 4092
# 当前时间步: 4093
# 当前时间步: 4094
# 当前时间步: 4095
# 当前时间步: 4096
# 当前时间步: 4097
# 当前时间步: 4098
# 当前时间步: 4099
# 当前时间步: 4100
# 当前时间步: 4101
# 当前时间步: 4102
# 当前时间步: 4103
# 当前时间步: 4104
# 当前时间步: 4105
# 当前时间步: 4106
# 当前时间步: 4107
# 当前时间步: 4108
# 当前时间步: 4109
# 当前时间步: 4110
# 当前时间步: 4111
# 当前时间步: 4112
# 当前时间步: 4113
# 当前时间步: 4114
# 当前时间步: 4115
# 当前时间步: 4116
# 当前时间步: 4117
# 当前时间步: 4118
# 当前时间步: 4119
# 当前时间步: 4120
# 当前时间步: 4121
# 当前时间步: 4122
# 当前时间步: 4123
# 当前时间步: 4124
# 当前时间步: 4125
# 当前时间步: 4126
# 当前时间步: 4127
# 当前时间步: 4128
# 当前时间步: 4129
# 当前时间步: 4130
# 当前时间步: 4131
# 当前时间步: 4132
# 当前时间步: 4133
# 当前时间步: 4134
# 当前时间步: 4135
# 当前时间步: 4136
# 当前时间步: 4137
# 当前时间步: 4138
# 当前时间步: 4139
# 当前时间步: 4140
# 当前时间步: 4141
# 当前时间步: 4142
# 当前时间步: 4143
# 当前时间步: 4144
# 当前时间步: 4145
# 当前时间步: 4146
# 当前时间步: 4147
# 当前时间步: 4148
# 当前时间步: 4149
# 当前时间步: 4150
# 当前时间步: 4151
# 当前时间步: 4152
# 当前时间步: 4153
# 当前时间步: 4154
# 当前时间步: 4155
# 当前时间步: 4156
# 当前时间步: 4157
# 当前时间步: 4158
# 当前时间步: 4159
# 当前时间步: 4160
# 当前时间步: 4161
# 当前时间步: 4162
# 当前时间步: 4163
# 当前时间步: 4164
# 当前时间步: 4165
# 当前时间步: 4166
# 当前时间步: 4167
# 当前时间步: 4168
# 当前时间步: 4169
# 当前时间步: 4170
# 当前时间步: 4171
# 当前时间步: 4172
# 当前时间步: 4173
# 当前时间步: 4174
# 当前时间步: 4175
# 当前时间步: 4176
# 当前时间步: 4177
# 当前时间步: 4178
# 当前时间步: 4179
# 当前时间步: 4180
# 当前时间步: 4181
# 当前时间步: 4182
# 当前时间步: 4183
# 当前时间步: 4184
# 当前时间步: 4185
# 当前时间步: 4186
# 当前时间步: 4187
# 当前时间步: 4188
# 当前时间步: 4189
# 当前时间步: 4190
# 当前时间步: 4191
# 当前时间步: 4192
# 当前时间步: 4193
# 当前时间步: 4194
# 当前时间步: 4195
# 当前时间步: 4196
# 当前时间步: 4197
# 当前时间步: 4198
# 当前时间步: 4199
# 当前时间步: 4200
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 23       |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 123      |
# |    time_elapsed    | 33       |
# |    total_timesteps | 4200     |
# | train/             |          |
# |    actor_loss      | -10.9    |
# |    critic_loss     | 0.696    |
# |    ent_coef        | 0.294    |
# |    ent_coef_loss   | -1.92    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4099     |
# ---------------------------------
# 当前时间步: 4201
# 当前时间步: 4202
# 当前时间步: 4203
# 当前时间步: 4204
# 当前时间步: 4205
# 当前时间步: 4206
# 当前时间步: 4207
# 当前时间步: 4208
# 当前时间步: 4209
# 当前时间步: 4210
# 当前时间步: 4211
# 当前时间步: 4212
# 当前时间步: 4213
# 当前时间步: 4214
# 当前时间步: 4215
# 当前时间步: 4216
# 当前时间步: 4217
# 当前时间步: 4218
# 当前时间步: 4219
# 当前时间步: 4220
# 当前时间步: 4221
# 当前时间步: 4222
# 当前时间步: 4223
# 当前时间步: 4224
# 当前时间步: 4225
# 当前时间步: 4226
# 当前时间步: 4227
# 当前时间步: 4228
# 当前时间步: 4229
# 当前时间步: 4230
# 当前时间步: 4231
# 当前时间步: 4232
# 当前时间步: 4233
# 当前时间步: 4234
# 当前时间步: 4235
# 当前时间步: 4236
# 当前时间步: 4237
# 当前时间步: 4238
# 当前时间步: 4239
# 当前时间步: 4240
# 当前时间步: 4241
# 当前时间步: 4242
# 当前时间步: 4243
# 当前时间步: 4244
# 当前时间步: 4245
# 当前时间步: 4246
# 当前时间步: 4247
# 当前时间步: 4248
# 当前时间步: 4249
# 当前时间步: 4250
# 当前时间步: 4251
# 当前时间步: 4252
# 当前时间步: 4253
# 当前时间步: 4254
# 当前时间步: 4255
# 当前时间步: 4256
# 当前时间步: 4257
# 当前时间步: 4258
# 当前时间步: 4259
# 当前时间步: 4260
# 当前时间步: 4261
# 当前时间步: 4262
# 当前时间步: 4263
# 当前时间步: 4264
# 当前时间步: 4265
# 当前时间步: 4266
# 当前时间步: 4267
# 当前时间步: 4268
# 当前时间步: 4269
# 当前时间步: 4270
# 当前时间步: 4271
# 当前时间步: 4272
# 当前时间步: 4273
# 当前时间步: 4274
# 当前时间步: 4275
# 当前时间步: 4276
# 当前时间步: 4277
# 当前时间步: 4278
# 当前时间步: 4279
# 当前时间步: 4280
# 当前时间步: 4281
# 当前时间步: 4282
# 当前时间步: 4283
# 当前时间步: 4284
# 当前时间步: 4285
# 当前时间步: 4286
# 当前时间步: 4287
# 当前时间步: 4288
# 当前时间步: 4289
# 当前时间步: 4290
# 当前时间步: 4291
# 当前时间步: 4292
# 当前时间步: 4293
# 当前时间步: 4294
# 当前时间步: 4295
# 当前时间步: 4296
# 当前时间步: 4297
# 当前时间步: 4298
# 当前时间步: 4299
# 当前时间步: 4300
# 当前时间步: 4301
# 当前时间步: 4302
# 当前时间步: 4303
# 当前时间步: 4304
# 当前时间步: 4305
# 当前时间步: 4306
# 当前时间步: 4307
# 当前时间步: 4308
# 当前时间步: 4309
# 当前时间步: 4310
# 当前时间步: 4311
# 当前时间步: 4312
# 当前时间步: 4313
# 当前时间步: 4314
# 当前时间步: 4315
# 当前时间步: 4316
# 当前时间步: 4317
# 当前时间步: 4318
# 当前时间步: 4319
# 当前时间步: 4320
# 当前时间步: 4321
# 当前时间步: 4322
# 当前时间步: 4323
# 当前时间步: 4324
# 当前时间步: 4325
# 当前时间步: 4326
# 当前时间步: 4327
# 当前时间步: 4328
# 当前时间步: 4329
# 当前时间步: 4330
# 当前时间步: 4331
# 当前时间步: 4332
# 当前时间步: 4333
# 当前时间步: 4334
# 当前时间步: 4335
# 当前时间步: 4336
# 当前时间步: 4337
# 当前时间步: 4338
# 当前时间步: 4339
# 当前时间步: 4340
# 当前时间步: 4341
# 当前时间步: 4342
# 当前时间步: 4343
# 当前时间步: 4344
# 当前时间步: 4345
# 当前时间步: 4346
# 当前时间步: 4347
# 当前时间步: 4348
# 当前时间步: 4349
# 当前时间步: 4350
# 当前时间步: 4351
# 当前时间步: 4352
# 当前时间步: 4353
# 当前时间步: 4354
# 当前时间步: 4355
# 当前时间步: 4356
# 当前时间步: 4357
# 当前时间步: 4358
# 当前时间步: 4359
# 当前时间步: 4360
# 当前时间步: 4361
# 当前时间步: 4362
# 当前时间步: 4363
# 当前时间步: 4364
# 当前时间步: 4365
# 当前时间步: 4366
# 当前时间步: 4367
# 当前时间步: 4368
# 当前时间步: 4369
# 当前时间步: 4370
# 当前时间步: 4371
# 当前时间步: 4372
# 当前时间步: 4373
# 当前时间步: 4374
# 当前时间步: 4375
# 当前时间步: 4376
# 当前时间步: 4377
# 当前时间步: 4378
# 当前时间步: 4379
# 当前时间步: 4380
# 当前时间步: 4381
# 当前时间步: 4382
# 当前时间步: 4383
# 当前时间步: 4384
# 当前时间步: 4385
# 当前时间步: 4386
# 当前时间步: 4387
# 当前时间步: 4388
# 当前时间步: 4389
# 当前时间步: 4390
# 当前时间步: 4391
# 当前时间步: 4392
# 当前时间步: 4393
# 当前时间步: 4394
# 当前时间步: 4395
# 当前时间步: 4396
# 当前时间步: 4397
# 当前时间步: 4398
# 当前时间步: 4399
# 当前时间步: 4400
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 23.2     |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 121      |
# |    time_elapsed    | 36       |
# |    total_timesteps | 4400     |
# | train/             |          |
# |    actor_loss      | -11.5    |
# |    critic_loss     | 0.625    |
# |    ent_coef        | 0.277    |
# |    ent_coef_loss   | -2.09    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4299     |
# ---------------------------------
# 当前时间步: 4401
# 当前时间步: 4402
# 当前时间步: 4403
# 当前时间步: 4404
# 当前时间步: 4405
# 当前时间步: 4406
# 当前时间步: 4407
# 当前时间步: 4408
# 当前时间步: 4409
# 当前时间步: 4410
# 当前时间步: 4411
# 当前时间步: 4412
# 当前时间步: 4413
# 当前时间步: 4414
# 当前时间步: 4415
# 当前时间步: 4416
# 当前时间步: 4417
# 当前时间步: 4418
# 当前时间步: 4419
# 当前时间步: 4420
# 当前时间步: 4421
# 当前时间步: 4422
# 当前时间步: 4423
# 当前时间步: 4424
# 当前时间步: 4425
# 当前时间步: 4426
# 当前时间步: 4427
# 当前时间步: 4428
# 当前时间步: 4429
# 当前时间步: 4430
# 当前时间步: 4431
# 当前时间步: 4432
# 当前时间步: 4433
# 当前时间步: 4434
# 当前时间步: 4435
# 当前时间步: 4436
# 当前时间步: 4437
# 当前时间步: 4438
# 当前时间步: 4439
# 当前时间步: 4440
# 当前时间步: 4441
# 当前时间步: 4442
# 当前时间步: 4443
# 当前时间步: 4444
# 当前时间步: 4445
# 当前时间步: 4446
# 当前时间步: 4447
# 当前时间步: 4448
# 当前时间步: 4449
# 当前时间步: 4450
# 当前时间步: 4451
# 当前时间步: 4452
# 当前时间步: 4453
# 当前时间步: 4454
# 当前时间步: 4455
# 当前时间步: 4456
# 当前时间步: 4457
# 当前时间步: 4458
# 当前时间步: 4459
# 当前时间步: 4460
# 当前时间步: 4461
# 当前时间步: 4462
# 当前时间步: 4463
# 当前时间步: 4464
# 当前时间步: 4465
# 当前时间步: 4466
# 当前时间步: 4467
# 当前时间步: 4468
# 当前时间步: 4469
# 当前时间步: 4470
# 当前时间步: 4471
# 当前时间步: 4472
# 当前时间步: 4473
# 当前时间步: 4474
# 当前时间步: 4475
# 当前时间步: 4476
# 当前时间步: 4477
# 当前时间步: 4478
# 当前时间步: 4479
# 当前时间步: 4480
# 当前时间步: 4481
# 当前时间步: 4482
# 当前时间步: 4483
# 当前时间步: 4484
# 当前时间步: 4485
# 当前时间步: 4486
# 当前时间步: 4487
# 当前时间步: 4488
# 当前时间步: 4489
# 当前时间步: 4490
# 当前时间步: 4491
# 当前时间步: 4492
# 当前时间步: 4493
# 当前时间步: 4494
# 当前时间步: 4495
# 当前时间步: 4496
# 当前时间步: 4497
# 当前时间步: 4498
# 当前时间步: 4499
# 当前时间步: 4500
# 当前时间步: 4501
# 当前时间步: 4502
# 当前时间步: 4503
# 当前时间步: 4504
# 当前时间步: 4505
# 当前时间步: 4506
# 当前时间步: 4507
# 当前时间步: 4508
# 当前时间步: 4509
# 当前时间步: 4510
# 当前时间步: 4511
# 当前时间步: 4512
# 当前时间步: 4513
# 当前时间步: 4514
# 当前时间步: 4515
# 当前时间步: 4516
# 当前时间步: 4517
# 当前时间步: 4518
# 当前时间步: 4519
# 当前时间步: 4520
# 当前时间步: 4521
# 当前时间步: 4522
# 当前时间步: 4523
# 当前时间步: 4524
# 当前时间步: 4525
# 当前时间步: 4526
# 当前时间步: 4527
# 当前时间步: 4528
# 当前时间步: 4529
# 当前时间步: 4530
# 当前时间步: 4531
# 当前时间步: 4532
# 当前时间步: 4533
# 当前时间步: 4534
# 当前时间步: 4535
# 当前时间步: 4536
# 当前时间步: 4537
# 当前时间步: 4538
# 当前时间步: 4539
# 当前时间步: 4540
# 当前时间步: 4541
# 当前时间步: 4542
# 当前时间步: 4543
# 当前时间步: 4544
# 当前时间步: 4545
# 当前时间步: 4546
# 当前时间步: 4547
# 当前时间步: 4548
# 当前时间步: 4549
# 当前时间步: 4550
# 当前时间步: 4551
# 当前时间步: 4552
# 当前时间步: 4553
# 当前时间步: 4554
# 当前时间步: 4555
# 当前时间步: 4556
# 当前时间步: 4557
# 当前时间步: 4558
# 当前时间步: 4559
# 当前时间步: 4560
# 当前时间步: 4561
# 当前时间步: 4562
# 当前时间步: 4563
# 当前时间步: 4564
# 当前时间步: 4565
# 当前时间步: 4566
# 当前时间步: 4567
# 当前时间步: 4568
# 当前时间步: 4569
# 当前时间步: 4570
# 当前时间步: 4571
# 当前时间步: 4572
# 当前时间步: 4573
# 当前时间步: 4574
# 当前时间步: 4575
# 当前时间步: 4576
# 当前时间步: 4577
# 当前时间步: 4578
# 当前时间步: 4579
# 当前时间步: 4580
# 当前时间步: 4581
# 当前时间步: 4582
# 当前时间步: 4583
# 当前时间步: 4584
# 当前时间步: 4585
# 当前时间步: 4586
# 当前时间步: 4587
# 当前时间步: 4588
# 当前时间步: 4589
# 当前时间步: 4590
# 当前时间步: 4591
# 当前时间步: 4592
# 当前时间步: 4593
# 当前时间步: 4594
# 当前时间步: 4595
# 当前时间步: 4596
# 当前时间步: 4597
# 当前时间步: 4598
# 当前时间步: 4599
# 当前时间步: 4600
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 23.1     |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 119      |
# |    time_elapsed    | 38       |
# |    total_timesteps | 4600     |
# | train/             |          |
# |    actor_loss      | -11.7    |
# |    critic_loss     | 0.534    |
# |    ent_coef        | 0.261    |
# |    ent_coef_loss   | -2.11    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4499     |
# ---------------------------------
# 当前时间步: 4601
# 当前时间步: 4602
# 当前时间步: 4603
# 当前时间步: 4604
# 当前时间步: 4605
# 当前时间步: 4606
# 当前时间步: 4607
# 当前时间步: 4608
# 当前时间步: 4609
# 当前时间步: 4610
# 当前时间步: 4611
# 当前时间步: 4612
# 当前时间步: 4613
# 当前时间步: 4614
# 当前时间步: 4615
# 当前时间步: 4616
# 当前时间步: 4617
# 当前时间步: 4618
# 当前时间步: 4619
# 当前时间步: 4620
# 当前时间步: 4621
# 当前时间步: 4622
# 当前时间步: 4623
# 当前时间步: 4624
# 当前时间步: 4625
# 当前时间步: 4626
# 当前时间步: 4627
# 当前时间步: 4628
# 当前时间步: 4629
# 当前时间步: 4630
# 当前时间步: 4631
# 当前时间步: 4632
# 当前时间步: 4633
# 当前时间步: 4634
# 当前时间步: 4635
# 当前时间步: 4636
# 当前时间步: 4637
# 当前时间步: 4638
# 当前时间步: 4639
# 当前时间步: 4640
# 当前时间步: 4641
# 当前时间步: 4642
# 当前时间步: 4643
# 当前时间步: 4644
# 当前时间步: 4645
# 当前时间步: 4646
# 当前时间步: 4647
# 当前时间步: 4648
# 当前时间步: 4649
# 当前时间步: 4650
# 当前时间步: 4651
# 当前时间步: 4652
# 当前时间步: 4653
# 当前时间步: 4654
# 当前时间步: 4655
# 当前时间步: 4656
# 当前时间步: 4657
# 当前时间步: 4658
# 当前时间步: 4659
# 当前时间步: 4660
# 当前时间步: 4661
# 当前时间步: 4662
# 当前时间步: 4663
# 当前时间步: 4664
# 当前时间步: 4665
# 当前时间步: 4666
# 当前时间步: 4667
# 当前时间步: 4668
# 当前时间步: 4669
# 当前时间步: 4670
# 当前时间步: 4671
# 当前时间步: 4672
# 当前时间步: 4673
# 当前时间步: 4674
# 当前时间步: 4675
# 当前时间步: 4676
# 当前时间步: 4677
# 当前时间步: 4678
# 当前时间步: 4679
# 当前时间步: 4680
# 当前时间步: 4681
# 当前时间步: 4682
# 当前时间步: 4683
# 当前时间步: 4684
# 当前时间步: 4685
# 当前时间步: 4686
# 当前时间步: 4687
# 当前时间步: 4688
# 当前时间步: 4689
# 当前时间步: 4690
# 当前时间步: 4691
# 当前时间步: 4692
# 当前时间步: 4693
# 当前时间步: 4694
# 当前时间步: 4695
# 当前时间步: 4696
# 当前时间步: 4697
# 当前时间步: 4698
# 当前时间步: 4699
# 当前时间步: 4700
# 当前时间步: 4701
# 当前时间步: 4702
# 当前时间步: 4703
# 当前时间步: 4704
# 当前时间步: 4705
# 当前时间步: 4706
# 当前时间步: 4707
# 当前时间步: 4708
# 当前时间步: 4709
# 当前时间步: 4710
# 当前时间步: 4711
# 当前时间步: 4712
# 当前时间步: 4713
# 当前时间步: 4714
# 当前时间步: 4715
# 当前时间步: 4716
# 当前时间步: 4717
# 当前时间步: 4718
# 当前时间步: 4719
# 当前时间步: 4720
# 当前时间步: 4721
# 当前时间步: 4722
# 当前时间步: 4723
# 当前时间步: 4724
# 当前时间步: 4725
# 当前时间步: 4726
# 当前时间步: 4727
# 当前时间步: 4728
# 当前时间步: 4729
# 当前时间步: 4730
# 当前时间步: 4731
# 当前时间步: 4732
# 当前时间步: 4733
# 当前时间步: 4734
# 当前时间步: 4735
# 当前时间步: 4736
# 当前时间步: 4737
# 当前时间步: 4738
# 当前时间步: 4739
# 当前时间步: 4740
# 当前时间步: 4741
# 当前时间步: 4742
# 当前时间步: 4743
# 当前时间步: 4744
# 当前时间步: 4745
# 当前时间步: 4746
# 当前时间步: 4747
# 当前时间步: 4748
# 当前时间步: 4749
# 当前时间步: 4750
# 当前时间步: 4751
# 当前时间步: 4752
# 当前时间步: 4753
# 当前时间步: 4754
# 当前时间步: 4755
# 当前时间步: 4756
# 当前时间步: 4757
# 当前时间步: 4758
# 当前时间步: 4759
# 当前时间步: 4760
# 当前时间步: 4761
# 当前时间步: 4762
# 当前时间步: 4763
# 当前时间步: 4764
# 当前时间步: 4765
# 当前时间步: 4766
# 当前时间步: 4767
# 当前时间步: 4768
# 当前时间步: 4769
# 当前时间步: 4770
# 当前时间步: 4771
# 当前时间步: 4772
# 当前时间步: 4773
# 当前时间步: 4774
# 当前时间步: 4775
# 当前时间步: 4776
# 当前时间步: 4777
# 当前时间步: 4778
# 当前时间步: 4779
# 当前时间步: 4780
# 当前时间步: 4781
# 当前时间步: 4782
# 当前时间步: 4783
# 当前时间步: 4784
# 当前时间步: 4785
# 当前时间步: 4786
# 当前时间步: 4787
# 当前时间步: 4788
# 当前时间步: 4789
# 当前时间步: 4790
# 当前时间步: 4791
# 当前时间步: 4792
# 当前时间步: 4793
# 当前时间步: 4794
# 当前时间步: 4795
# 当前时间步: 4796
# 当前时间步: 4797
# 当前时间步: 4798
# 当前时间步: 4799
# 当前时间步: 4800
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 23.1     |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 118      |
# |    time_elapsed    | 40       |
# |    total_timesteps | 4800     |
# | train/             |          |
# |    actor_loss      | -11.5    |
# |    critic_loss     | 0.546    |
# |    ent_coef        | 0.246    |
# |    ent_coef_loss   | -2.15    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4699     |
# ---------------------------------
# 当前时间步: 4801
# 当前时间步: 4802
# 当前时间步: 4803
# 当前时间步: 4804
# 当前时间步: 4805
# 当前时间步: 4806
# 当前时间步: 4807
# 当前时间步: 4808
# 当前时间步: 4809
# 当前时间步: 4810
# 当前时间步: 4811
# 当前时间步: 4812
# 当前时间步: 4813
# 当前时间步: 4814
# 当前时间步: 4815
# 当前时间步: 4816
# 当前时间步: 4817
# 当前时间步: 4818
# 当前时间步: 4819
# 当前时间步: 4820
# 当前时间步: 4821
# 当前时间步: 4822
# 当前时间步: 4823
# 当前时间步: 4824
# 当前时间步: 4825
# 当前时间步: 4826
# 当前时间步: 4827
# 当前时间步: 4828
# 当前时间步: 4829
# 当前时间步: 4830
# 当前时间步: 4831
# 当前时间步: 4832
# 当前时间步: 4833
# 当前时间步: 4834
# 当前时间步: 4835
# 当前时间步: 4836
# 当前时间步: 4837
# 当前时间步: 4838
# 当前时间步: 4839
# 当前时间步: 4840
# 当前时间步: 4841
# 当前时间步: 4842
# 当前时间步: 4843
# 当前时间步: 4844
# 当前时间步: 4845
# 当前时间步: 4846
# 当前时间步: 4847
# 当前时间步: 4848
# 当前时间步: 4849
# 当前时间步: 4850
# 当前时间步: 4851
# 当前时间步: 4852
# 当前时间步: 4853
# 当前时间步: 4854
# 当前时间步: 4855
# 当前时间步: 4856
# 当前时间步: 4857
# 当前时间步: 4858
# 当前时间步: 4859
# 当前时间步: 4860
# 当前时间步: 4861
# 当前时间步: 4862
# 当前时间步: 4863
# 当前时间步: 4864
# 当前时间步: 4865
# 当前时间步: 4866
# 当前时间步: 4867
# 当前时间步: 4868
# 当前时间步: 4869
# 当前时间步: 4870
# 当前时间步: 4871
# 当前时间步: 4872
# 当前时间步: 4873
# 当前时间步: 4874
# 当前时间步: 4875
# 当前时间步: 4876
# 当前时间步: 4877
# 当前时间步: 4878
# 当前时间步: 4879
# 当前时间步: 4880
# 当前时间步: 4881
# 当前时间步: 4882
# 当前时间步: 4883
# 当前时间步: 4884
# 当前时间步: 4885
# 当前时间步: 4886
# 当前时间步: 4887
# 当前时间步: 4888
# 当前时间步: 4889
# 当前时间步: 4890
# 当前时间步: 4891
# 当前时间步: 4892
# 当前时间步: 4893
# 当前时间步: 4894
# 当前时间步: 4895
# 当前时间步: 4896
# 当前时间步: 4897
# 当前时间步: 4898
# 当前时间步: 4899
# 当前时间步: 4900
# 当前时间步: 4901
# 当前时间步: 4902
# 当前时间步: 4903
# 当前时间步: 4904
# 当前时间步: 4905
# 当前时间步: 4906
# 当前时间步: 4907
# 当前时间步: 4908
# 当前时间步: 4909
# 当前时间步: 4910
# 当前时间步: 4911
# 当前时间步: 4912
# 当前时间步: 4913
# 当前时间步: 4914
# 当前时间步: 4915
# 当前时间步: 4916
# 当前时间步: 4917
# 当前时间步: 4918
# 当前时间步: 4919
# 当前时间步: 4920
# 当前时间步: 4921
# 当前时间步: 4922
# 当前时间步: 4923
# 当前时间步: 4924
# 当前时间步: 4925
# 当前时间步: 4926
# 当前时间步: 4927
# 当前时间步: 4928
# 当前时间步: 4929
# 当前时间步: 4930
# 当前时间步: 4931
# 当前时间步: 4932
# 当前时间步: 4933
# 当前时间步: 4934
# 当前时间步: 4935
# 当前时间步: 4936
# 当前时间步: 4937
# 当前时间步: 4938
# 当前时间步: 4939
# 当前时间步: 4940
# 当前时间步: 4941
# 当前时间步: 4942
# 当前时间步: 4943
# 当前时间步: 4944
# 当前时间步: 4945
# 当前时间步: 4946
# 当前时间步: 4947
# 当前时间步: 4948
# 当前时间步: 4949
# 当前时间步: 4950
# 当前时间步: 4951
# 当前时间步: 4952
# 当前时间步: 4953
# 当前时间步: 4954
# 当前时间步: 4955
# 当前时间步: 4956
# 当前时间步: 4957
# 当前时间步: 4958
# 当前时间步: 4959
# 当前时间步: 4960
# 当前时间步: 4961
# 当前时间步: 4962
# 当前时间步: 4963
# 当前时间步: 4964
# 当前时间步: 4965
# 当前时间步: 4966
# 当前时间步: 4967
# 当前时间步: 4968
# 当前时间步: 4969
# 当前时间步: 4970
# 当前时间步: 4971
# 当前时间步: 4972
# 当前时间步: 4973
# 当前时间步: 4974
# 当前时间步: 4975
# 当前时间步: 4976
# 当前时间步: 4977
# 当前时间步: 4978
# 当前时间步: 4979
# 当前时间步: 4980
# 当前时间步: 4981
# 当前时间步: 4982
# 当前时间步: 4983
# 当前时间步: 4984
# 当前时间步: 4985
# 当前时间步: 4986
# 当前时间步: 4987
# 当前时间步: 4988
# 当前时间步: 4989
# 当前时间步: 4990
# 当前时间步: 4991
# 当前时间步: 4992
# 当前时间步: 4993
# 当前时间步: 4994
# 当前时间步: 4995
# 当前时间步: 4996
# 当前时间步: 4997
# 当前时间步: 4998
# 当前时间步: 4999
# 当前时间步: 5000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 23       |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 117      |
# |    time_elapsed    | 42       |
# |    total_timesteps | 5000     |
# | train/             |          |
# |    actor_loss      | -11.5    |
# |    critic_loss     | 0.505    |
# |    ent_coef        | 0.232    |
# |    ent_coef_loss   | -2.36    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4899     |
# ---------------------------------

# %%
import torch as th
# 加载训练好的模型
model = SAC.load("EpsilonGreedy")

# 重置环境，获取初始状态
state, _ = env.reset()

# 确保状态是一个 NumPy 数组
state = np.array(state)

# 初始化随机策略记录均值、标准差和动作的列表
means1 = []
stds1 = []
actions1 = []#记录随机性策略的动作

# 注意，分了两个循环，一个是随机性策略，一个是确定性策略；不同情形下的状态游走路径可能是不一样的

# 随机性策略交互
for t in range(T):
    # 将状态转换为 PyTorch 张量，并添加批量维度
    state_tensor = th.tensor(state, dtype=th.float32).unsqueeze(0)
    action1, _ = model.predict(state_tensor, deterministic=False) #  随机策略，高斯分布采样+裁剪

    # 获取动作分布参数
    mean_actions, log_std, _ = model.policy.actor.get_action_dist_params(state_tensor)
    std = th.exp(log_std)
    # 记录均值和标准差
    means1.append(mean_actions.detach().numpy().flatten())
    stds1.append(std.detach().numpy().flatten())
    actions1.append(action1)
    # 与环境进行交互
    next_state, reward, terminated, truncated, info = env.step(action1)

    # 更新状态
    state = next_state

# 将均值、标准差和实际动作转换为 NumPy 数组
means1 = np.array(means1)
stds1 = np.array(stds1)
actions1 = np.array(actions1)

k = len(probs)
self_n = state[:k]
self_average_rewards = state[k:2*k]
total_reward = np.sum(self_n * self_average_rewards)
# 打印最终状态和总收益
formatted_probs = [f"{prob:.4f}" for prob in probs]
print("伯努利多臂老虎机的概率为：", formatted_probs)
print("随机策略拉臂次数:", state[1:k])
print("随机策略臂收益均值:",np.round(state[k:2*k], 4))
print("随机策略臂收益方差:",np.round(state[2*k:3*k], 4))
print("随机策略总收益:", total_reward)


# 重置环境，获取初始状态
state, _ = env.reset()
# 初始化确定策略记录均值、标准差和动作的列表
means2 = []
stds2 = []
actions2 = []#记录确定性策略的动作

# 确定性策略交互
for t in range(T):
    # 将状态转换为 PyTorch 张量，并添加批量维度
    state_tensor = th.tensor(state, dtype=th.float32).unsqueeze(0)
    action2, _ = model.predict(state_tensor, deterministic=True) #  确定性策略，均值动作
    # 记录动作
    actions2.append(action2)
    # 获取动作分布参数
    mean_actions, log_std, _ = model.policy.actor.get_action_dist_params(state_tensor)
    std = th.exp(log_std)
    # 记录均值和标准差
    means2.append(mean_actions.detach().numpy().flatten())
    stds2.append(std.detach().numpy().flatten())
    # 与环境进行交互
    next_state, reward, terminated, truncated, info = env.step(action2)

    # 更新状态
    state = next_state
# 将实际动作转换为 NumPy 数组
means2 = np.array(means2)
stds2 = np.array(stds2)
actions2 = np.array(actions2)
time_steps = np.arange(T)

# 绘制随机策略均值和标准差随时间步的变化
# plt.figure(figsize=(12, 6))
# plt.subplot(2, 1, 1)
# plt.errorbar(time_steps, means1.flatten(), yerr=stds1.flatten(), fmt='-o', ecolor='r', capsize=5, label='mean and std of stochastic epsilons')
# plt.legend()

# 绘制确定策略均值和标准差随时间步的变化

# plt.subplot(2, 1, 1)
# plt.errorbar(time_steps, means2.flatten(), yerr=stds2.flatten(), fmt='-o', ecolor='r', capsize=5, label='mean and std of deterministic epsilons')
# plt.xlabel('time')
# plt.ylabel('Epsilon')
# plt.title('Changes in the mean and standard deviation of epsilons over time steps')
# plt.legend()


# 绘制随机策略的动作随时间步的变化
plt.subplot(2, 1, 2)
plt.plot(time_steps, actions1.flatten(), '-o', label='stochastic actions')
# 绘制确定策略的动作随时间步的变化
plt.plot(time_steps, actions2.flatten(), '-o', label='deterministic actions')
plt.xlabel('time')
plt.ylabel('Epsilon')
plt.title('Stochastic and deterministic actions over time steps in an episode')
plt.legend()

plt.tight_layout()
plt.show()

k = len(probs)
self_n = state[:k]
self_average_rewards = state[k:2*k]
total_reward = np.sum(self_n * self_average_rewards)
# 打印最终状态和总收益
formatted_probs = [f"{prob:.4f}" for prob in probs]
print("伯努利多臂老虎机的概率为：", formatted_probs)

print("确定策略拉臂次数:", state[:k])
print("确定策略臂收益均值:",np.round(state[k:2*k], 4))
print("确定策略臂收益方差:",np.round(state[2*k:3*k], 4))
print("确定策略总收益:", total_reward)
# Out:
# 伯努利多臂老虎机的概率为： ['0.4170', '0.7203', '0.0001', '0.3023', '0.1468']
# 随机策略拉臂次数: [19.  1.  6.  4.]
# 随机策略臂收益均值: [0.5    0.6842 0.     0.     0.25  ]
# 随机策略臂收益方差: [0.25   0.2161 0.     0.     0.1875]
# 随机策略总收益: 24.0
# 伯努利多臂老虎机的概率为： ['0.4170', '0.7203', '0.0001', '0.3023', '0.1468']
# 确定策略拉臂次数: [50.  0.  0.  0.  0.]
# 确定策略臂收益均值: [0.38 0.   0.   0.   0.  ]
# 确定策略臂收益方差: [0.2356 0.     0.     0.     0.    ]
# 确定策略总收益: 19.0
